# %% [markdown]
# ## Logistic Regression Experiments

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import random
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
from sklearn.metrics import f1_score
import optuna
from optuna.samplers import TPESampler
import joblib
import gensim.downloader as api

# %%
random.seed(42)
np.random.seed(42)

# %% [markdown]
# - Load the train and test files

# %%
train_df = pd.read_csv("train_data.csv")
val_df  = pd.read_csv("val_data.csv")
test_df  = pd.read_csv("test_data.csv")

# %%
print(f"Train: {len(train_df):>6} rows")
print(f" Val : {len(val_df):>6} rows")
print(f" Test: {len(test_df):>6} rows")
# Out:
# Train:   8000 rows
#  Val :   1000 rows
#  Test:   1000 rows

# %% [markdown]
# ## Word2Vec - Experiment 1 (GloVe Twitter Word2Vec)

# %%
# Load the pre-trained GloVe Twitter vectors 
wv = api.load("glove-twitter-200")

# %%
# helper to compute mean embedding for a document
def doc_vector(doc, wv_model):
    tokens = [tok for tok in doc.split() if tok in wv_model]
    if not tokens:
        return np.zeros(wv_model.vector_size)
    return np.mean([wv_model[t] for t in tokens], axis=0)

# %%
# Build feature matrices from raw text
X_train = np.vstack(train_df["text"].astype(str).apply(lambda d: doc_vector(d, wv)))
X_val   = np.vstack(val_df  ["text"].astype(str).apply(lambda d: doc_vector(d, wv)))
X_test  = np.vstack(test_df ["text"].astype(str).apply(lambda d: doc_vector(d, wv)))

y_train = train_df["sentiment_id"]
y_val   = val_df  ["sentiment_id"]
y_test  = test_df ["sentiment_id"]

# %% [markdown]
# - Hyperparameter tuning

# %%
from xgboost import XGBClassifier

# %%
# XGB hyperparameters
def objective(trial):
    
    n_estimators = trial.suggest_int("n_estimators", 50, 300)
    max_depth = trial.suggest_int("max_depth", 3, 10)
    learning_rate = trial.suggest_float("learning_rate", 0.01, 0.3)
    subsample = trial.suggest_float("subsample", 0.6, 1.0)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.6, 1.0)
    reg_alpha = trial.suggest_float("reg_alpha", 0.0, 1.0)
    reg_lambda = trial.suggest_float("reg_lambda", 0.0, 1.0)

    clf = XGBClassifier(
        objective="multi:softmax",
        num_class=3,
        eval_metric="mlogloss",
        random_state=42,
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        reg_alpha=reg_alpha,
        reg_lambda=reg_lambda
    )

    clf.fit(X_train, y_train)

    preds = clf.predict(X_val)
    return f1_score(y_val, preds, average="macro")

# %%
sampler = TPESampler(seed=42)
study   = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=20)

print("Best macro-F1:", study.best_value)
print("Best params:")
for k, v in study.best_params.items():
    print(f"  {k}: {v}")
# Out:
# [I 2025-06-24 21:26:43,196] A new study created in memory with name: no-name-0fa33dcf-5380-422a-9042-5834bf23e7e1
# [I 2025-06-24 21:26:51,036] Trial 0 finished with value: 0.5628970230673528 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.22227824312530747, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'reg_alpha': 0.15599452033620265, 'reg_lambda': 0.05808361216819946}. Best is trial 0 with value: 0.5628970230673528.
# [I 2025-06-24 21:27:06,042] Trial 1 finished with value: 0.5941104974078976 and parameters: {'n_estimators': 267, 'max_depth': 7, 'learning_rate': 0.21534104756085318, 'subsample': 0.608233797718321, 'colsample_bytree': 0.9879639408647978, 'reg_alpha': 0.8324426408004217, 'reg_lambda': 0.21233911067827616}. Best is trial 1 with value: 0.5941104974078976.
# [I 2025-06-24 21:27:08,755] Trial 2 finished with value: 0.5746904531196303 and parameters: {'n_estimators': 95, 'max_depth': 4, 'learning_rate': 0.09823025045826593, 'subsample': 0.8099025726528951, 'colsample_bytree': 0.7727780074568463, 'reg_alpha': 0.2912291401980419, 'reg_lambda': 0.6118528947223795}. Best is trial 1 with value: 0.5941104974078976.
# [I 2025-06-24 21:27:12,407] Trial 3 finished with value: 0.5582298849899061 and parameters: {'n_estimators': 85, 'max_depth': 5, 'learning_rate': 0.11624493455517058, 'subsample': 0.7824279936868144, 'colsample_bytree': 0.9140703845572055, 'reg_alpha': 0.19967378215835974, 'reg_lambda': 0.5142344384136116}. Best is trial 1 with value: 0.5941104974078976.
# [I 2025-06-24 21:27:16,508] Trial 4 finished with value: 0.6079653029863376 and parameters: {'n_estimators': 198, 'max_depth': 3, 'learning_rate': 0.1861880070514171, 'subsample': 0.6682096494749166, 'colsample_bytree': 0.6260206371941118, 'reg_alpha': 0.9488855372533332, 'reg_lambda': 0.9656320330745594}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:27:25,748] Trial 5 finished with value: 0.5670037133681253 and parameters: {'n_estimators': 252, 'max_depth': 5, 'learning_rate': 0.03832491306185132, 'subsample': 0.8736932106048627, 'colsample_bytree': 0.7760609974958406, 'reg_alpha': 0.12203823484477883, 'reg_lambda': 0.4951769101112702}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:27:36,653] Trial 6 finished with value: 0.5271912240148847 and parameters: {'n_estimators': 58, 'max_depth': 10, 'learning_rate': 0.0850461946640049, 'subsample': 0.8650089137415928, 'colsample_bytree': 0.7246844304357644, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 0.5467102793432796}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:27:49,660] Trial 7 finished with value: 0.566064664198931 and parameters: {'n_estimators': 96, 'max_depth': 10, 'learning_rate': 0.2347885187747232, 'subsample': 0.9757995766256756, 'colsample_bytree': 0.9579309401710595, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:27:52,107] Trial 8 finished with value: 0.4595855737838099 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.023115913784056037, 'subsample': 0.7301321323053057, 'colsample_bytree': 0.7554709158757928, 'reg_alpha': 0.2713490317738959, 'reg_lambda': 0.8287375091519293}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:27:58,565] Trial 9 finished with value: 0.5899824342743023 and parameters: {'n_estimators': 139, 'max_depth': 5, 'learning_rate': 0.16738186411589207, 'subsample': 0.6563696899899051, 'colsample_bytree': 0.9208787923016158, 'reg_alpha': 0.07455064367977082, 'reg_lambda': 0.9868869366005173}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:28:08,503] Trial 10 finished with value: 0.590898189341096 and parameters: {'n_estimators': 210, 'max_depth': 7, 'learning_rate': 0.29116576212848116, 'subsample': 0.6998501323364759, 'colsample_bytree': 0.6058163500649457, 'reg_alpha': 0.907664795282518, 'reg_lambda': 0.7303668952070097}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:28:25,227] Trial 11 finished with value: 0.5926593493844585 and parameters: {'n_estimators': 295, 'max_depth': 7, 'learning_rate': 0.1855041862810203, 'subsample': 0.606799971042974, 'colsample_bytree': 0.8586208359261052, 'reg_alpha': 0.9708685513840705, 'reg_lambda': 0.254722570471121}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:28:40,197] Trial 12 finished with value: 0.5906129163886259 and parameters: {'n_estimators': 214, 'max_depth': 8, 'learning_rate': 0.23787193073921878, 'subsample': 0.6033985907293916, 'colsample_bytree': 0.8507883200006244, 'reg_alpha': 0.764079369025238, 'reg_lambda': 0.2646596329637791}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:28:50,277] Trial 13 finished with value: 0.6029007655762404 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.197314985227843, 'subsample': 0.6916807777598375, 'colsample_bytree': 0.9862778301767895, 'reg_alpha': 0.7647148866919213, 'reg_lambda': 0.34279928826631634}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:28:55,516] Trial 14 finished with value: 0.6042385514355105 and parameters: {'n_estimators': 197, 'max_depth': 3, 'learning_rate': 0.13705774857242897, 'subsample': 0.7274898944305879, 'colsample_bytree': 0.6898693025872835, 'reg_alpha': 0.6748974402458979, 'reg_lambda': 0.3885568536631039}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:28:58,790] Trial 15 finished with value: 0.5867219605660738 and parameters: {'n_estimators': 185, 'max_depth': 3, 'learning_rate': 0.13845814766387085, 'subsample': 0.7500704828802731, 'colsample_bytree': 0.6783715954207381, 'reg_alpha': 0.6310843435389654, 'reg_lambda': 0.716952101802523}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:29:01,929] Trial 16 finished with value: 0.6017830648169137 and parameters: {'n_estimators': 154, 'max_depth': 3, 'learning_rate': 0.14365830709192037, 'subsample': 0.6577039151126511, 'colsample_bytree': 0.6053816161954919, 'reg_alpha': 0.4225816924164582, 'reg_lambda': 0.3882706745672633}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:29:09,112] Trial 17 finished with value: 0.5772037856257649 and parameters: {'n_estimators': 223, 'max_depth': 4, 'learning_rate': 0.0644073932524273, 'subsample': 0.930573919743892, 'colsample_bytree': 0.6740335125680293, 'reg_alpha': 0.7059388023638252, 'reg_lambda': 0.02091356648340381}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:29:18,469] Trial 18 finished with value: 0.5776572490194303 and parameters: {'n_estimators': 178, 'max_depth': 6, 'learning_rate': 0.26882523872246494, 'subsample': 0.7585850375345765, 'colsample_bytree': 0.7201591693811747, 'reg_alpha': 0.9914136052154511, 'reg_lambda': 0.666535639307719}. Best is trial 4 with value: 0.6079653029863376.
# [I 2025-06-24 21:29:21,963] Trial 19 finished with value: 0.5861227603037326 and parameters: {'n_estimators': 119, 'max_depth': 3, 'learning_rate': 0.16926229768261536, 'subsample': 0.6748397462452165, 'colsample_bytree': 0.6384028347505858, 'reg_alpha': 0.43609983357228016, 'reg_lambda': 0.8290986858715536}. Best is trial 4 with value: 0.6079653029863376.
# Best macro-F1: 0.6079653029863376
# Best params:
#   n_estimators: 198
#   max_depth: 3
#   learning_rate: 0.1861880070514171
#   subsample: 0.6682096494749166
#   colsample_bytree: 0.6260206371941118
#   reg_alpha: 0.9488855372533332
#   reg_lambda: 0.9656320330745594

# %%
best = study.best_params

pipeline = Pipeline([
    ("clf", XGBClassifier(
        objective="multi:softmax",
        num_class=3,
        eval_metric="mlogloss",
        random_state=42,
        n_estimators     = best["n_estimators"],
        max_depth        = best["max_depth"],
        learning_rate    = best["learning_rate"],
        subsample        = best["subsample"],
        colsample_bytree = best["colsample_bytree"],
        reg_alpha        = best["reg_alpha"],
        reg_lambda       = best["reg_lambda"]
    ))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('clf',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=0.6260206371941118, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric='mlogloss',
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.1861880070514171, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=3,
#                                max_leaves=None, min_child_weight=None,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=198,
#                                n_jobs=None, num_class=3, ...))])

# %%
y_pred = pipeline.predict(X_test)
print(classification_report(test_df["sentiment_id"],y_pred,target_names=["Negative", "Neutral", "Positive"]))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.75      0.68      0.71       160
#      Neutral       0.48      0.13      0.20       101
#     Positive       0.86      0.97      0.91       739
#
#     accuracy                           0.84      1000
#    macro avg       0.70      0.59      0.61      1000
# weighted avg       0.81      0.84      0.81      1000

# %%
# Plot the confusion matrix 
cm = confusion_matrix(test_df["sentiment_id"], y_pred)
labels = ["Negative", "Neutral", "Positive"]

fig, ax = plt.subplots()
im = ax.imshow(cm, cmap="Blues")        
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)  
ax.set_xticks(np.arange(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticks(np.arange(len(labels)))
ax.set_yticklabels(labels)
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_title("Confusion Matrix")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha="center", va="center")

plt.tight_layout()
plt.show()

# %%
joblib.dump(pipeline, "xgb_word2vec_experiment1.pkl")
# Out:
# ['xgb_word2vec_experiment1.pkl']

# %%
def oov_rate(texts, wv_model):
    total, oov = 0, 0
    for doc in texts:
        for tok in str(doc).split():
            total += 1
            if tok not in wv_model:
                oov += 1
    return oov/total

print("GloVe-Twitter OOV:", oov_rate(train_df["text"], wv))
# Out:
# GloVe-Twitter OOV: 0.22578407727792613
