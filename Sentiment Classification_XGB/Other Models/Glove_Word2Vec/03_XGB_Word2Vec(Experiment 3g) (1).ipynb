# %% [markdown]
# ## XGB Regression Experiments

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import random
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
from sklearn.metrics import f1_score
import optuna
from optuna.samplers import TPESampler
import joblib
from xgboost import XGBClassifier

# %%
random.seed(42)
np.random.seed(42)

# %% [markdown]
# - Load the train and test files

# %%
train_df = pd.read_csv("train_data.csv")
val_df  = pd.read_csv("val_data.csv")
test_df  = pd.read_csv("test_data.csv")

# %%
print(f"Train: {len(train_df):>6} rows")
print(f" Val : {len(val_df):>6} rows")
print(f" Test: {len(test_df):>6} rows")
# Out:
# Train:   8000 rows
#  Val :   1000 rows
#  Test:   1000 rows

# %% [markdown]
# ## Word2Vec - Experiment 3g (Word2Vec trained on SIA reviews)

# %%
import nltk
import re, ftfy, string
from nltk.corpus import stopwords
import string

stop_words = set(stopwords.words('english'))
punct_table = str.maketrans('', '', string.punctuation)

# %%
def clean_text_pipeline(text):
    # Fix Unicode glitches
    text = ftfy.fix_text(text)

    # Strip HTML tags and URLs
    text = re.sub(r'<[^>]+>', ' ', text)
    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    # # Strip non-ASCII (e.g. Äô,â€)
    # text = re.sub(r'[^\x20-\x7E]', ' ', text)

    # # Lowercase 
    # text = text.lower()

    # # Remove Punctuation 
    # text = text.translate(punct_table)

    # # Remove whitespace
    # text = re.sub(r'\s+', ' ', text).strip()

    # Split into words for stopword removal (next step)
    words = text.split() 

    # Drop stopwords
    words = [w for w in words if w not in stopwords.words('english')]

    return " ".join(words)

# %%
def w2v_features(texts, vector_size, window, min_count, sg, epochs, workers):
    tok = texts.astype(str).apply(word_tokenize)
    model = Word2Vec(
      sentences   = tok.tolist(),
      vector_size = vector_size,
      window      = window,
      min_count   = min_count,
      sg          = sg,
      epochs      = epochs,
      workers     = workers,
      seed        = 42
    )
    # avg pooling
    def dv(toks):
        vecs = [model.wv[w] for w in toks if w in model.wv]
        return np.mean(vecs, axis=0) if vecs else np.zeros(vector_size)
    return np.vstack(tok.apply(dv).values), model

# %%
train_df["clean_text"] = train_df["text"].astype(str).apply(clean_text_pipeline)
val_df  ["clean_text"] = val_df  ["text"].astype(str).apply(clean_text_pipeline)
train_texts = train_df["clean_text"] 
val_texts   = val_df["clean_text"]
y_train = train_df["sentiment_id"]
y_val   = val_df["sentiment_id"]

# %% [markdown]
# - Applying Optimal Parameters for Retraining and Evaluation on the Test Set

# %%
def objective(trial):
    # Word2Vec params
    vs = trial.suggest_int("vector_size", 100, 300, step=100)
    win   = trial.suggest_int("window", 3, 7)
    mc    = trial.suggest_int("min_count", 1, 10)
    sg    = trial.suggest_int("sg", 0, 1)       # 0=CBOW, 1=skip-gram
    epochs= trial.suggest_int("epochs",5,20)
    X_tr, w2v = w2v_features(train_texts, vs, win, mc, sg, epochs, workers=4)
    X_va      = np.vstack(val_texts.astype(str)
                          .apply(lambda d: np.mean(
                              [w2v.wv[w] for w in word_tokenize(d) if w in w2v.wv],
                              axis=0) if d else np.zeros(vs)
                          ).values)

    # --- XGBoost hyperparameters ---
    n_estimators     = trial.suggest_int("n_estimators", 50, 300)
    max_depth        = trial.suggest_int("max_depth", 3, 10)
    learning_rate    = trial.suggest_float("learning_rate", 0.01, 0.3)
    subsample        = trial.suggest_float("subsample", 0.6, 1.0)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.6, 1.0)
    reg_alpha        = trial.suggest_float("reg_alpha", 0.0, 1.0)
    reg_lambda       = trial.suggest_float("reg_lambda", 0.0, 1.0)

    clf = XGBClassifier(
        objective        = "multi:softmax",  # or "binary:logistic" if binary
        num_class        = 3,                # adjust to your number of classes
        eval_metric      = "mlogloss",
        random_state     = 42,
        n_estimators     = n_estimators,
        max_depth        = max_depth,
        learning_rate    = learning_rate,
        subsample        = subsample,
        colsample_bytree = colsample_bytree,
        reg_alpha        = reg_alpha,
        reg_lambda       = reg_lambda
    )
    clf.fit(X_tr, y_train)
    preds = clf.predict(X_va)
    return f1_score(y_val, preds, average="macro")

# %%
sampler = TPESampler(seed=42, n_startup_trials=10)
study   = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=20)
print("Best macro-F1:", study.best_value)
print("Best hyperparameters:", study.best_params)
# Out:
# [I 2025-07-05 03:22:33,079] A new study created in memory with name: no-name-e20d654a-1c2c-4f93-aa2a-0b8cb6103edf
# [I 2025-07-05 03:22:44,737] Trial 0 finished with value: 0.6589750446052456 and parameters: {'vector_size': 200, 'window': 7, 'min_count': 8, 'sg': 1, 'epochs': 7, 'n_estimators': 89, 'max_depth': 3, 'learning_rate': 0.2611910822747312, 'subsample': 0.8404460046972835, 'colsample_bytree': 0.8832290311184181, 'reg_alpha': 0.020584494295802447, 'reg_lambda': 0.9699098521619943}. Best is trial 0 with value: 0.6589750446052456.
# [I 2025-07-05 03:23:05,751] Trial 1 finished with value: 0.6209343959343959 and parameters: {'vector_size': 300, 'window': 4, 'min_count': 2, 'sg': 0, 'epochs': 9, 'n_estimators': 181, 'max_depth': 6, 'learning_rate': 0.09445645065743215, 'subsample': 0.8447411578889518, 'colsample_bytree': 0.6557975442608167, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 0 with value: 0.6589750446052456.
# [I 2025-07-05 03:23:28,091] Trial 2 finished with value: 0.5882039023993094 and parameters: {'vector_size': 200, 'window': 6, 'min_count': 2, 'sg': 1, 'epochs': 14, 'n_estimators': 61, 'max_depth': 7, 'learning_rate': 0.059451995869314544, 'subsample': 0.6260206371941118, 'colsample_bytree': 0.9795542149013333, 'reg_alpha': 0.9656320330745594, 'reg_lambda': 0.8083973481164611}. Best is trial 0 with value: 0.6589750446052456.
# [I 2025-07-05 03:23:34,399] Trial 3 finished with value: 0.605023187976436 and parameters: {'vector_size': 100, 'window': 3, 'min_count': 7, 'sg': 0, 'epochs': 6, 'n_estimators': 174, 'max_depth': 3, 'learning_rate': 0.2737029166028468, 'subsample': 0.7035119926400067, 'colsample_bytree': 0.8650089137415928, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 0 with value: 0.6589750446052456.
# [I 2025-07-05 03:23:59,517] Trial 4 finished with value: 0.6502485756337804 and parameters: {'vector_size': 200, 'window': 3, 'min_count': 10, 'sg': 1, 'epochs': 20, 'n_estimators': 274, 'max_depth': 7, 'learning_rate': 0.2773435281567039, 'subsample': 0.6353970008207678, 'colsample_bytree': 0.6783931449676581, 'reg_alpha': 0.045227288910538066, 'reg_lambda': 0.32533033076326434}. Best is trial 0 with value: 0.6589750446052456.
# [I 2025-07-05 03:24:09,981] Trial 5 finished with value: 0.6442789787083946 and parameters: {'vector_size': 200, 'window': 4, 'min_count': 9, 'sg': 0, 'epochs': 9, 'n_estimators': 186, 'max_depth': 4, 'learning_rate': 0.2426371244186715, 'subsample': 0.6298202574719083, 'colsample_bytree': 0.9947547746402069, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 0 with value: 0.6589750446052456.
# [I 2025-07-05 03:24:28,808] Trial 6 finished with value: 0.6169073861200111 and parameters: {'vector_size': 100, 'window': 7, 'min_count': 8, 'sg': 1, 'epochs': 17, 'n_estimators': 68, 'max_depth': 5, 'learning_rate': 0.04360202726228762, 'subsample': 0.9452413703502374, 'colsample_bytree': 0.8493192507310232, 'reg_alpha': 0.3308980248526492, 'reg_lambda': 0.06355835028602363}. Best is trial 0 with value: 0.6589750446052456.
# [I 2025-07-05 03:24:44,172] Trial 7 finished with value: 0.6696968030185584 and parameters: {'vector_size': 100, 'window': 4, 'min_count': 8, 'sg': 1, 'epochs': 19, 'n_estimators': 168, 'max_depth': 3, 'learning_rate': 0.21684098829466855, 'subsample': 0.9043140194467589, 'colsample_bytree': 0.8245108790277985, 'reg_alpha': 0.770967179954561, 'reg_lambda': 0.49379559636439074}. Best is trial 7 with value: 0.6696968030185584.
# [I 2025-07-05 03:24:59,303] Trial 8 finished with value: 0.5426135059575463 and parameters: {'vector_size': 200, 'window': 5, 'min_count': 1, 'sg': 0, 'epochs': 5, 'n_estimators': 209, 'max_depth': 5, 'learning_rate': 0.1574855004377638, 'subsample': 0.9630265895704372, 'colsample_bytree': 0.69971689165955, 'reg_alpha': 0.41038292303562973, 'reg_lambda': 0.7555511385430487}. Best is trial 7 with value: 0.6696968030185584.
# [I 2025-07-05 03:25:15,581] Trial 9 finished with value: 0.5911449911449912 and parameters: {'vector_size': 100, 'window': 3, 'min_count': 3, 'sg': 0, 'epochs': 19, 'n_estimators': 252, 'max_depth': 8, 'learning_rate': 0.2627235711544381, 'subsample': 0.9214688307596458, 'colsample_bytree': 0.6746280235544143, 'reg_alpha': 0.8925589984899778, 'reg_lambda': 0.5393422419156507}. Best is trial 7 with value: 0.6696968030185584.
# [I 2025-07-05 03:25:52,703] Trial 10 finished with value: 0.6667840283284975 and parameters: {'vector_size': 300, 'window': 5, 'min_count': 5, 'sg': 1, 'epochs': 14, 'n_estimators': 125, 'max_depth': 10, 'learning_rate': 0.18673823803172804, 'subsample': 0.746848881453861, 'colsample_bytree': 0.7518416973680894, 'reg_alpha': 0.6782537997512522, 'reg_lambda': 0.6971558983400944}. Best is trial 7 with value: 0.6696968030185584.
# [I 2025-07-05 03:26:26,557] Trial 11 finished with value: 0.6696808653521255 and parameters: {'vector_size': 300, 'window': 5, 'min_count': 5, 'sg': 1, 'epochs': 14, 'n_estimators': 126, 'max_depth': 10, 'learning_rate': 0.19228091700989777, 'subsample': 0.7539964820128596, 'colsample_bytree': 0.7507659086856399, 'reg_alpha': 0.6090738634337447, 'reg_lambda': 0.6768180580956151}. Best is trial 7 with value: 0.6696968030185584.
# [I 2025-07-05 03:27:01,041] Trial 12 finished with value: 0.6552657140516566 and parameters: {'vector_size': 300, 'window': 4, 'min_count': 5, 'sg': 1, 'epochs': 16, 'n_estimators': 128, 'max_depth': 10, 'learning_rate': 0.2052060033241295, 'subsample': 0.7987586652315627, 'colsample_bytree': 0.766618801481957, 'reg_alpha': 0.6028231464816249, 'reg_lambda': 0.6159815374121003}. Best is trial 7 with value: 0.6696968030185584.
# [I 2025-07-05 03:27:22,468] Trial 13 finished with value: 0.6569504285685607 and parameters: {'vector_size': 100, 'window': 6, 'min_count': 6, 'sg': 1, 'epochs': 11, 'n_estimators': 131, 'max_depth': 9, 'learning_rate': 0.12164069190549212, 'subsample': 0.8819708330406043, 'colsample_bytree': 0.8084448535981558, 'reg_alpha': 0.5580719994292282, 'reg_lambda': 0.36573394253216385}. Best is trial 7 with value: 0.6696968030185584.
# [I 2025-07-05 03:28:04,805] Trial 14 finished with value: 0.6706080353203167 and parameters: {'vector_size': 300, 'window': 5, 'min_count': 4, 'sg': 1, 'epochs': 17, 'n_estimators': 224, 'max_depth': 8, 'learning_rate': 0.21233708008625185, 'subsample': 0.7381159952100154, 'colsample_bytree': 0.6054548993685063, 'reg_alpha': 0.7871464458547138, 'reg_lambda': 0.8920898610159673}. Best is trial 14 with value: 0.6706080353203167.
# [I 2025-07-05 03:28:51,475] Trial 15 finished with value: 0.6421274942537553 and parameters: {'vector_size': 300, 'window': 6, 'min_count': 4, 'sg': 1, 'epochs': 18, 'n_estimators': 225, 'max_depth': 8, 'learning_rate': 0.2223657421945108, 'subsample': 0.9900223113198996, 'colsample_bytree': 0.9255974822311328, 'reg_alpha': 0.8094674677589321, 'reg_lambda': 0.9811915917272181}. Best is trial 14 with value: 0.6706080353203167.
# [I 2025-07-05 03:29:09,774] Trial 16 finished with value: 0.6690129526736168 and parameters: {'vector_size': 100, 'window': 4, 'min_count': 7, 'sg': 1, 'epochs': 16, 'n_estimators': 237, 'max_depth': 6, 'learning_rate': 0.15170973729936457, 'subsample': 0.691346484168823, 'colsample_bytree': 0.6015244262142765, 'reg_alpha': 0.752063359204209, 'reg_lambda': 0.8795007958880703}. Best is trial 14 with value: 0.6706080353203167.
# [I 2025-07-05 03:29:38,046] Trial 17 finished with value: 0.6531887810986645 and parameters: {'vector_size': 200, 'window': 4, 'min_count': 10, 'sg': 1, 'epochs': 20, 'n_estimators': 293, 'max_depth': 8, 'learning_rate': 0.29686667177472437, 'subsample': 0.8914471497857412, 'colsample_bytree': 0.6015448122990825, 'reg_alpha': 0.9978055208928529, 'reg_lambda': 0.45049032373889986}. Best is trial 14 with value: 0.6706080353203167.
# [I 2025-07-05 03:30:07,697] Trial 18 finished with value: 0.6387718653153336 and parameters: {'vector_size': 300, 'window': 5, 'min_count': 4, 'sg': 1, 'epochs': 18, 'n_estimators': 168, 'max_depth': 4, 'learning_rate': 0.16197332180494725, 'subsample': 0.7906252538035308, 'colsample_bytree': 0.8084876635994097, 'reg_alpha': 0.8449075745964763, 'reg_lambda': 0.13740306729154583}. Best is trial 14 with value: 0.6706080353203167.
# [I 2025-07-05 03:30:25,924] Trial 19 finished with value: 0.6504227376600917 and parameters: {'vector_size': 100, 'window': 5, 'min_count': 7, 'sg': 1, 'epochs': 12, 'n_estimators': 154, 'max_depth': 9, 'learning_rate': 0.2277057815388866, 'subsample': 0.8411668195303771, 'colsample_bytree': 0.9184818289870509, 'reg_alpha': 0.4913805796216437, 'reg_lambda': 0.2652252156386269}. Best is trial 14 with value: 0.6706080353203167.
# Best macro-F1: 0.6706080353203167
# Best hyperparameters: {'vector_size': 300, 'window': 5, 'min_count': 4, 'sg': 1, 'epochs': 17, 'n_estimators': 224, 'max_depth': 8, 'learning_rate': 0.21233708008625185, 'subsample': 0.7381159952100154, 'colsample_bytree': 0.6054548993685063, 'reg_alpha': 0.7871464458547138, 'reg_lambda': 0.8920898610159673}

# %%
best = study.best_params
sentences = [word_tokenize(txt) for txt in train_df["text"].astype(str)]
w2v_final = Word2Vec(
    sentences   = sentences,
    vector_size = best["vector_size"],
    window      = best["window"],
    min_count   = best["min_count"],
    sg          = best["sg"],
    epochs      = best["epochs"],
    workers     = 4,
    seed        = 42
)

# %%
# average word2vec vectors for a document
def doc_vector(doc):
    toks = word_tokenize(str(doc))
    vecs = [w2v_final.wv[t] for t in toks if t in w2v_final.wv]
    return np.mean(vecs, axis=0) if vecs else np.zeros(w2v_final.vector_size)

# %%
# Build feature matrices
train_df["clean_text"] = train_df["text"].astype(str).apply(clean_text_pipeline)
test_df ["clean_text"] = test_df ["text"].astype(str).apply(clean_text_pipeline)
X_train = np.vstack(train_df["clean_text"].apply(doc_vector).tolist())
X_test  = np.vstack(test_df ["clean_text"].apply(doc_vector).tolist())
y_train = train_df["sentiment_id"]
y_test  = test_df ["sentiment_id"]

# %%
from xgboost import XGBClassifier

# %%
clf_final = XGBClassifier(
    objective        = "multi:softmax",   
    num_class        = 3,                 # 3 class
    eval_metric      = "mlogloss",
    random_state     = 42,
    n_estimators     = best["n_estimators"],
    max_depth        = best["max_depth"],
    learning_rate    = best["learning_rate"],
    subsample        = best["subsample"],
    colsample_bytree = best["colsample_bytree"],
    reg_alpha        = best["reg_alpha"],
    reg_lambda       = best["reg_lambda"]
)
clf_final.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6054548993685063, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='mlogloss', feature_types=None, feature_weights=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.21233708008625185,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=224, n_jobs=None, num_class=3, ...)

# %%
y_test_pred = clf_final.predict(X_test)
print(classification_report(y_test,y_test_pred,target_names=["Negative", "Neutral", "Positive"]))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.76      0.68      0.72       160
#      Neutral       0.51      0.18      0.26       101
#     Positive       0.88      0.97      0.92       739
#
#     accuracy                           0.85      1000
#    macro avg       0.72      0.61      0.63      1000
# weighted avg       0.82      0.85      0.82      1000

# %%
cm = confusion_matrix(test_df["sentiment_id"], y_test_pred)
labels = ["Negative", "Neutral", "Positive"]

fig, ax = plt.subplots()
im = ax.imshow(cm, cmap="Blues")
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

ax.set_xticks(np.arange(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticks(np.arange(len(labels)))
ax.set_yticklabels(labels)
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_title("Confusion Matrix")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha="center", va="center")

plt.tight_layout()
plt.show()

# %%
joblib.dump(clf_final, "XGB_word2vec_experiment3g.pkl")
# Out:
# ['XGB_word2vec_experiment3g.pkl']
