# %% [markdown]
# ## XGB Experiments

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import random
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
from sklearn.metrics import f1_score
import optuna
from optuna.samplers import TPESampler
import joblib
import gensim.downloader as api
from xgboost import XGBClassifier

# %%
random.seed(42)
np.random.seed(42)

# %% [markdown]
# - Load the train and test files

# %%
train_df = pd.read_csv("train_data.csv")
val_df  = pd.read_csv("val_data.csv")
test_df  = pd.read_csv("test_data.csv")

# %%
print(f"Train: {len(train_df):>6} rows")
print(f" Val : {len(val_df):>6} rows")
print(f" Test: {len(test_df):>6} rows")
# Out:
# Train:   8000 rows
#  Val :   1000 rows
#  Test:   1000 rows

# %% [markdown]
# ## Word2Vec - Experiment 2 (Google Word2Vec)

# %%
# Load the Google's pre-trained Word2Vec
wv = api.load("word2vec-google-news-300")

# %%
# helper to compute mean embedding for a document
def doc_vector(doc, wv_model):
    tokens = [tok for tok in doc.split() if tok in wv_model]
    if not tokens:
        return np.zeros(wv_model.vector_size)
    return np.mean([wv_model[t] for t in tokens], axis=0)

# %%
# Build feature matrices from raw text
X_train = np.vstack(train_df["text"].astype(str).apply(lambda d: doc_vector(d, wv)))
X_val   = np.vstack(val_df  ["text"].astype(str).apply(lambda d: doc_vector(d, wv)))
X_test  = np.vstack(test_df ["text"].astype(str).apply(lambda d: doc_vector(d, wv)))

y_train = train_df["sentiment_id"]
y_val   = val_df  ["sentiment_id"]
y_test  = test_df ["sentiment_id"]

# %% [markdown]
# - Hyperparameter tuning

# %%
# XGB hyperparameters
def objective(trial):
    
    n_estimators = trial.suggest_int("n_estimators", 50, 300)
    max_depth = trial.suggest_int("max_depth", 3, 10)
    learning_rate = trial.suggest_float("learning_rate", 0.01, 0.3)
    subsample = trial.suggest_float("subsample", 0.6, 1.0)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.6, 1.0)
    reg_alpha = trial.suggest_float("reg_alpha", 0.0, 1.0)
    reg_lambda = trial.suggest_float("reg_lambda", 0.0, 1.0)

    clf = XGBClassifier(
        objective="multi:softmax",
        num_class=3,
        eval_metric="mlogloss",
        random_state=42,
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        reg_alpha=reg_alpha,
        reg_lambda=reg_lambda
    )

    clf.fit(X_train, y_train)

    preds = clf.predict(X_val)
    return f1_score(y_val, preds, average="macro")

# %%
sampler = TPESampler(seed=42)
study   = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=20)

print("Best macro-F1:", study.best_value)
print("Best params:")
for k, v in study.best_params.items():
    print(f"  {k}: {v}")
# Out:
# [I 2025-06-24 23:50:14,602] A new study created in memory with name: no-name-535ab098-4674-4340-8d24-129c3d053843
# [I 2025-06-24 23:50:53,051] Trial 0 finished with value: 0.5896230853782084 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.22227824312530747, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'reg_alpha': 0.15599452033620265, 'reg_lambda': 0.05808361216819946}. Best is trial 0 with value: 0.5896230853782084.
# [I 2025-06-24 23:51:25,020] Trial 1 finished with value: 0.607469345930181 and parameters: {'n_estimators': 267, 'max_depth': 7, 'learning_rate': 0.21534104756085318, 'subsample': 0.608233797718321, 'colsample_bytree': 0.9879639408647978, 'reg_alpha': 0.8324426408004217, 'reg_lambda': 0.21233911067827616}. Best is trial 1 with value: 0.607469345930181.
# [I 2025-06-24 23:51:34,296] Trial 2 finished with value: 0.6079278702518139 and parameters: {'n_estimators': 95, 'max_depth': 4, 'learning_rate': 0.09823025045826593, 'subsample': 0.8099025726528951, 'colsample_bytree': 0.7727780074568463, 'reg_alpha': 0.2912291401980419, 'reg_lambda': 0.6118528947223795}. Best is trial 2 with value: 0.6079278702518139.
# [I 2025-06-24 23:51:45,368] Trial 3 finished with value: 0.616265440658052 and parameters: {'n_estimators': 85, 'max_depth': 5, 'learning_rate': 0.11624493455517058, 'subsample': 0.7824279936868144, 'colsample_bytree': 0.9140703845572055, 'reg_alpha': 0.19967378215835974, 'reg_lambda': 0.5142344384136116}. Best is trial 3 with value: 0.616265440658052.
# [I 2025-06-24 23:51:53,675] Trial 4 finished with value: 0.6552380512337596 and parameters: {'n_estimators': 198, 'max_depth': 3, 'learning_rate': 0.1861880070514171, 'subsample': 0.6682096494749166, 'colsample_bytree': 0.6260206371941118, 'reg_alpha': 0.9488855372533332, 'reg_lambda': 0.9656320330745594}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:52:31,280] Trial 5 finished with value: 0.6144778130448416 and parameters: {'n_estimators': 252, 'max_depth': 5, 'learning_rate': 0.03832491306185132, 'subsample': 0.8736932106048627, 'colsample_bytree': 0.7760609974958406, 'reg_alpha': 0.12203823484477883, 'reg_lambda': 0.4951769101112702}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:53:11,651] Trial 6 finished with value: 0.5523617859378723 and parameters: {'n_estimators': 58, 'max_depth': 10, 'learning_rate': 0.0850461946640049, 'subsample': 0.8650089137415928, 'colsample_bytree': 0.7246844304357644, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 0.5467102793432796}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:54:03,273] Trial 7 finished with value: 0.5927580787469421 and parameters: {'n_estimators': 96, 'max_depth': 10, 'learning_rate': 0.2347885187747232, 'subsample': 0.9757995766256756, 'colsample_bytree': 0.9579309401710595, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 0.9218742350231168}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:54:10,463] Trial 8 finished with value: 0.4811344465842855 and parameters: {'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.023115913784056037, 'subsample': 0.7301321323053057, 'colsample_bytree': 0.7554709158757928, 'reg_alpha': 0.2713490317738959, 'reg_lambda': 0.8287375091519293}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:54:26,019] Trial 9 finished with value: 0.6380301188062105 and parameters: {'n_estimators': 139, 'max_depth': 5, 'learning_rate': 0.16738186411589207, 'subsample': 0.6563696899899051, 'colsample_bytree': 0.9208787923016158, 'reg_alpha': 0.07455064367977082, 'reg_lambda': 0.9868869366005173}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:54:56,342] Trial 10 finished with value: 0.6189281470971612 and parameters: {'n_estimators': 210, 'max_depth': 7, 'learning_rate': 0.29116576212848116, 'subsample': 0.6998501323364759, 'colsample_bytree': 0.6058163500649457, 'reg_alpha': 0.907664795282518, 'reg_lambda': 0.7303668952070097}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:55:10,863] Trial 11 finished with value: 0.649937613281525 and parameters: {'n_estimators': 173, 'max_depth': 3, 'learning_rate': 0.1696755056406023, 'subsample': 0.6054439187294712, 'colsample_bytree': 0.8788623593360378, 'reg_alpha': 0.740703639474553, 'reg_lambda': 0.9919501327452349}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:55:27,252] Trial 12 finished with value: 0.6372223761643214 and parameters: {'n_estimators': 201, 'max_depth': 3, 'learning_rate': 0.16866551860010004, 'subsample': 0.601714089202831, 'colsample_bytree': 0.8548132432909736, 'reg_alpha': 0.7349288129117235, 'reg_lambda': 0.7679687770189166}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:55:41,776] Trial 13 finished with value: 0.6268659072129533 and parameters: {'n_estimators': 182, 'max_depth': 3, 'learning_rate': 0.13733640092436256, 'subsample': 0.6716990001073604, 'colsample_bytree': 0.8488073013225127, 'reg_alpha': 0.995051760134625, 'reg_lambda': 0.9960165317474355}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:56:33,554] Trial 14 finished with value: 0.6215170797160761 and parameters: {'n_estimators': 240, 'max_depth': 8, 'learning_rate': 0.18913676036556212, 'subsample': 0.7320225452827609, 'colsample_bytree': 0.8398964423849187, 'reg_alpha': 0.7116993054437019, 'reg_lambda': 0.3122349359221165}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:56:47,401] Trial 15 finished with value: 0.6446104044840822 and parameters: {'n_estimators': 297, 'max_depth': 3, 'learning_rate': 0.2864345481322443, 'subsample': 0.6516719563699208, 'colsample_bytree': 0.6962007238120261, 'reg_alpha': 0.7777116035069411, 'reg_lambda': 0.8507099850175411}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:57:24,422] Trial 16 finished with value: 0.6518479304046315 and parameters: {'n_estimators': 154, 'max_depth': 4, 'learning_rate': 0.249642525639318, 'subsample': 0.7551196176766958, 'colsample_bytree': 0.6082858712967962, 'reg_alpha': 0.6157559564970051, 'reg_lambda': 0.6625170984836}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:58:06,111] Trial 17 finished with value: 0.6102798482637788 and parameters: {'n_estimators': 138, 'max_depth': 6, 'learning_rate': 0.25807918098807064, 'subsample': 0.753244933235902, 'colsample_bytree': 0.6164402821353379, 'reg_alpha': 0.4017587606711791, 'reg_lambda': 0.6660456183567609}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:58:26,198] Trial 18 finished with value: 0.6497825254932149 and parameters: {'n_estimators': 165, 'max_depth': 4, 'learning_rate': 0.25375578560121054, 'subsample': 0.9438599500782205, 'colsample_bytree': 0.6538258722483655, 'reg_alpha': 0.5596158930967834, 'reg_lambda': 0.35839028479054197}. Best is trial 4 with value: 0.6552380512337596.
# [I 2025-06-24 23:58:58,730] Trial 19 finished with value: 0.608424649842141 and parameters: {'n_estimators': 218, 'max_depth': 6, 'learning_rate': 0.19670819973803977, 'subsample': 0.7743873107974812, 'colsample_bytree': 0.6579963793536174, 'reg_alpha': 0.9961662472542548, 'reg_lambda': 0.392936877718503}. Best is trial 4 with value: 0.6552380512337596.
# Best macro-F1: 0.6552380512337596
# Best params:
#   n_estimators: 198
#   max_depth: 3
#   learning_rate: 0.1861880070514171
#   subsample: 0.6682096494749166
#   colsample_bytree: 0.6260206371941118
#   reg_alpha: 0.9488855372533332
#   reg_lambda: 0.9656320330745594

# %%
best = study.best_params

pipeline = Pipeline([
    ("clf", XGBClassifier(
        objective="multi:softmax",
        num_class=3,
        eval_metric="mlogloss",
        random_state=42,
        n_estimators     = best["n_estimators"],
        max_depth        = best["max_depth"],
        learning_rate    = best["learning_rate"],
        subsample        = best["subsample"],
        colsample_bytree = best["colsample_bytree"],
        reg_alpha        = best["reg_alpha"],
        reg_lambda       = best["reg_lambda"]
    ))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('clf',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=0.6260206371941118, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric='mlogloss',
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.1861880070514171, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=3,
#                                max_leaves=None, min_child_weight=None,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=198,
#                                n_jobs=None, num_class=3, ...))])

# %%
y_pred = pipeline.predict(X_test)
print(classification_report(test_df["sentiment_id"],y_pred,target_names=["Negative", "Neutral", "Positive"]))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.70      0.65      0.68       160
#      Neutral       0.53      0.19      0.28       101
#     Positive       0.88      0.97      0.92       739
#
#     accuracy                           0.84      1000
#    macro avg       0.70      0.60      0.62      1000
# weighted avg       0.81      0.84      0.82      1000

# %%
# Plot the confusion matrix 
cm = confusion_matrix(test_df["sentiment_id"], y_pred)
labels = ["Negative", "Neutral", "Positive"]

fig, ax = plt.subplots()
im = ax.imshow(cm, cmap="Blues")        
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)  
ax.set_xticks(np.arange(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticks(np.arange(len(labels)))
ax.set_yticklabels(labels)
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_title("Confusion Matrix")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha="center", va="center")

plt.tight_layout()
plt.show()

# %%
joblib.dump(pipeline, "xgb_word2vec_experiment2.pkl")
# Out:
# ['xgb_word2vec_experiment2.pkl']

# %%
def oov_rate(texts, wv_model):
    total, oov = 0, 0
    for doc in texts:
        for tok in str(doc).split():
            total += 1
            if tok not in wv_model:
                oov += 1
    return oov/total

print("GoogleNews OOV:",  oov_rate(train_df["text"], wv))
# Out:
# GoogleNews OOV: 0.2146318824701953
