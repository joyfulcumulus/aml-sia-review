# %% [markdown]
# ## XGB Regression Experiments

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import random
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
from sklearn.metrics import f1_score
import optuna
from optuna.samplers import TPESampler
import joblib
from xgboost import XGBClassifier

# %%
random.seed(42)
np.random.seed(42)

# %% [markdown]
# - Load the train and test files

# %%
train_df = pd.read_csv("train_data.csv")
val_df  = pd.read_csv("val_data.csv")
test_df  = pd.read_csv("test_data.csv")

# %%
print(f"Train: {len(train_df):>6} rows")
print(f" Val : {len(val_df):>6} rows")
print(f" Test: {len(test_df):>6} rows")
# Out:
# Train:   8000 rows
#  Val :   1000 rows
#  Test:   1000 rows

# %% [markdown]
# ## Word2Vec - Experiment 3b (Word2Vec trained on SIA reviews)

# %%
import nltk
import re, ftfy, string
from nltk.corpus import stopwords
import string

stop_words = set(stopwords.words('english'))
punct_table = str.maketrans('', '', string.punctuation)

# %%
def clean_text_pipeline(text):
    # Fix Unicode glitches
    text = ftfy.fix_text(text)

    # Strip HTML tags and URLs
    text = re.sub(r'<[^>]+>', ' ', text)
    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    # Strip non-ASCII (e.g. Äô,â€)
    #text = re.sub(r'[^\x20-\x7E]', ' ', text)

    # Lowercase 
    #text = text.lower()

    # Remove Punctuation 
    #text = text.translate(punct_table)

    # Remove whitespace
    #text = re.sub(r'\s+', ' ', text).strip()

    # # Split into words for stopword removal (next step)
    # words = text.split() 

    # # Drop stopwords
    # words = [w for w in words if w not in stopwords.words('english')]

    return (text)

# %%
def w2v_features(texts, vector_size, window, min_count, sg, epochs, workers):
    tok = texts.astype(str).apply(word_tokenize)
    model = Word2Vec(
      sentences   = tok.tolist(),
      vector_size = vector_size,
      window      = window,
      min_count   = min_count,
      sg          = sg,
      epochs      = epochs,
      workers     = workers,
      seed        = 42
    )
    # avg pooling
    def dv(toks):
        vecs = [model.wv[w] for w in toks if w in model.wv]
        return np.mean(vecs, axis=0) if vecs else np.zeros(vector_size)
    return np.vstack(tok.apply(dv).values), model

# %%
train_df["clean_text"] = train_df["text"].astype(str).apply(clean_text_pipeline)
val_df  ["clean_text"] = val_df  ["text"].astype(str).apply(clean_text_pipeline)
train_texts = train_df["clean_text"] 
val_texts   = val_df["clean_text"]
y_train = train_df["sentiment_id"]
y_val   = val_df["sentiment_id"]

# %% [markdown]
# - Applying Optimal Parameters for Retraining and Evaluation on the Test Set

# %%
def objective(trial):
    # Word2Vec params
    vs = trial.suggest_int("vector_size", 100, 300, step=100)
    win   = trial.suggest_int("window", 3, 7)
    mc    = trial.suggest_int("min_count", 1, 10)
    sg    = trial.suggest_int("sg", 0, 1)       # 0=CBOW, 1=skip-gram
    epochs= trial.suggest_int("epochs",5,20)
    X_tr, w2v = w2v_features(train_texts, vs, win, mc, sg, epochs, workers=4)
    X_va      = np.vstack(val_texts.astype(str)
                          .apply(lambda d: np.mean(
                              [w2v.wv[w] for w in word_tokenize(d) if w in w2v.wv],
                              axis=0) if d else np.zeros(vs)
                          ).values)

    # --- XGBoost hyperparameters ---
    n_estimators     = trial.suggest_int("n_estimators", 50, 300)
    max_depth        = trial.suggest_int("max_depth", 3, 10)
    learning_rate    = trial.suggest_float("learning_rate", 0.01, 0.3)
    subsample        = trial.suggest_float("subsample", 0.6, 1.0)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.6, 1.0)
    reg_alpha        = trial.suggest_float("reg_alpha", 0.0, 1.0)
    reg_lambda       = trial.suggest_float("reg_lambda", 0.0, 1.0)

    clf = XGBClassifier(
        objective        = "multi:softmax",  # or "binary:logistic" if binary
        num_class        = 3,                # adjust to your number of classes
        eval_metric      = "mlogloss",
        random_state     = 42,
        n_estimators     = n_estimators,
        max_depth        = max_depth,
        learning_rate    = learning_rate,
        subsample        = subsample,
        colsample_bytree = colsample_bytree,
        reg_alpha        = reg_alpha,
        reg_lambda       = reg_lambda
    )
    clf.fit(X_tr, y_train)
    preds = clf.predict(X_va)
    return f1_score(y_val, preds, average="macro")

# %%
sampler = TPESampler(seed=42, n_startup_trials=10)
study   = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=20)
print("Best macro-F1:", study.best_value)
print("Best hyperparameters:", study.best_params)
# Out:
# [I 2025-07-05 02:33:04,797] A new study created in memory with name: no-name-96fc0064-ac2b-4cbf-be99-c844d74b684b
# [I 2025-07-05 02:33:22,258] Trial 0 finished with value: 0.6442239136091595 and parameters: {'vector_size': 200, 'window': 7, 'min_count': 8, 'sg': 1, 'epochs': 7, 'n_estimators': 89, 'max_depth': 3, 'learning_rate': 0.2611910822747312, 'subsample': 0.8404460046972835, 'colsample_bytree': 0.8832290311184181, 'reg_alpha': 0.020584494295802447, 'reg_lambda': 0.9699098521619943}. Best is trial 0 with value: 0.6442239136091595.
# [I 2025-07-05 02:33:46,698] Trial 1 finished with value: 0.5597279579108281 and parameters: {'vector_size': 300, 'window': 4, 'min_count': 2, 'sg': 0, 'epochs': 9, 'n_estimators': 181, 'max_depth': 6, 'learning_rate': 0.09445645065743215, 'subsample': 0.8447411578889518, 'colsample_bytree': 0.6557975442608167, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 0 with value: 0.6442239136091595.
# [I 2025-07-05 02:34:19,904] Trial 2 finished with value: 0.5947228779087187 and parameters: {'vector_size': 200, 'window': 6, 'min_count': 2, 'sg': 1, 'epochs': 14, 'n_estimators': 61, 'max_depth': 7, 'learning_rate': 0.059451995869314544, 'subsample': 0.6260206371941118, 'colsample_bytree': 0.9795542149013333, 'reg_alpha': 0.9656320330745594, 'reg_lambda': 0.8083973481164611}. Best is trial 0 with value: 0.6442239136091595.
# [I 2025-07-05 02:34:29,861] Trial 3 finished with value: 0.5787239910204103 and parameters: {'vector_size': 100, 'window': 3, 'min_count': 7, 'sg': 0, 'epochs': 6, 'n_estimators': 174, 'max_depth': 3, 'learning_rate': 0.2737029166028468, 'subsample': 0.7035119926400067, 'colsample_bytree': 0.8650089137415928, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 0 with value: 0.6442239136091595.
# [I 2025-07-05 02:35:03,086] Trial 4 finished with value: 0.6172256678743032 and parameters: {'vector_size': 200, 'window': 3, 'min_count': 10, 'sg': 1, 'epochs': 20, 'n_estimators': 274, 'max_depth': 7, 'learning_rate': 0.2773435281567039, 'subsample': 0.6353970008207678, 'colsample_bytree': 0.6783931449676581, 'reg_alpha': 0.045227288910538066, 'reg_lambda': 0.32533033076326434}. Best is trial 0 with value: 0.6442239136091595.
# [I 2025-07-05 02:35:16,111] Trial 5 finished with value: 0.6287969522869186 and parameters: {'vector_size': 200, 'window': 4, 'min_count': 9, 'sg': 0, 'epochs': 9, 'n_estimators': 186, 'max_depth': 4, 'learning_rate': 0.2426371244186715, 'subsample': 0.6298202574719083, 'colsample_bytree': 0.9947547746402069, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 0 with value: 0.6442239136091595.
# [I 2025-07-05 02:35:43,180] Trial 6 finished with value: 0.5732988728031659 and parameters: {'vector_size': 100, 'window': 7, 'min_count': 8, 'sg': 1, 'epochs': 17, 'n_estimators': 68, 'max_depth': 5, 'learning_rate': 0.04360202726228762, 'subsample': 0.9452413703502374, 'colsample_bytree': 0.8493192507310232, 'reg_alpha': 0.3308980248526492, 'reg_lambda': 0.06355835028602363}. Best is trial 0 with value: 0.6442239136091595.
# [I 2025-07-05 02:36:07,095] Trial 7 finished with value: 0.6631338385113829 and parameters: {'vector_size': 100, 'window': 4, 'min_count': 8, 'sg': 1, 'epochs': 19, 'n_estimators': 168, 'max_depth': 3, 'learning_rate': 0.21684098829466855, 'subsample': 0.9043140194467589, 'colsample_bytree': 0.8245108790277985, 'reg_alpha': 0.770967179954561, 'reg_lambda': 0.49379559636439074}. Best is trial 7 with value: 0.6631338385113829.
# [I 2025-07-05 02:36:24,124] Trial 8 finished with value: 0.5471947898117983 and parameters: {'vector_size': 200, 'window': 5, 'min_count': 1, 'sg': 0, 'epochs': 5, 'n_estimators': 209, 'max_depth': 5, 'learning_rate': 0.1574855004377638, 'subsample': 0.9630265895704372, 'colsample_bytree': 0.69971689165955, 'reg_alpha': 0.41038292303562973, 'reg_lambda': 0.7555511385430487}. Best is trial 7 with value: 0.6631338385113829.
# [I 2025-07-05 02:36:43,042] Trial 9 finished with value: 0.613972397395118 and parameters: {'vector_size': 100, 'window': 3, 'min_count': 3, 'sg': 0, 'epochs': 19, 'n_estimators': 252, 'max_depth': 8, 'learning_rate': 0.2627235711544381, 'subsample': 0.9214688307596458, 'colsample_bytree': 0.6746280235544143, 'reg_alpha': 0.8925589984899778, 'reg_lambda': 0.5393422419156507}. Best is trial 7 with value: 0.6631338385113829.
# [I 2025-07-05 02:37:25,917] Trial 10 finished with value: 0.6099036023807622 and parameters: {'vector_size': 300, 'window': 5, 'min_count': 5, 'sg': 1, 'epochs': 14, 'n_estimators': 125, 'max_depth': 10, 'learning_rate': 0.18673823803172804, 'subsample': 0.746848881453861, 'colsample_bytree': 0.7518416973680894, 'reg_alpha': 0.6782537997512522, 'reg_lambda': 0.6971558983400944}. Best is trial 7 with value: 0.6631338385113829.
# [I 2025-07-05 02:37:45,092] Trial 11 finished with value: 0.6547926336449711 and parameters: {'vector_size': 100, 'window': 7, 'min_count': 6, 'sg': 1, 'epochs': 10, 'n_estimators': 116, 'max_depth': 3, 'learning_rate': 0.2177447979088, 'subsample': 0.8520470909561684, 'colsample_bytree': 0.895980602376029, 'reg_alpha': 0.6090738634337447, 'reg_lambda': 0.911140437047386}. Best is trial 7 with value: 0.6631338385113829.
# [I 2025-07-05 02:38:05,085] Trial 12 finished with value: 0.6749847954122309 and parameters: {'vector_size': 100, 'window': 6, 'min_count': 5, 'sg': 1, 'epochs': 10, 'n_estimators': 126, 'max_depth': 3, 'learning_rate': 0.20396231249344568, 'subsample': 0.8834113249233835, 'colsample_bytree': 0.927082500165246, 'reg_alpha': 0.6028231464816249, 'reg_lambda': 0.9980071027057287}. Best is trial 12 with value: 0.6749847954122309.
# [I 2025-07-05 02:38:26,680] Trial 13 finished with value: 0.6502374554206827 and parameters: {'vector_size': 100, 'window': 6, 'min_count': 5, 'sg': 1, 'epochs': 12, 'n_estimators': 133, 'max_depth': 4, 'learning_rate': 0.12164069190549212, 'subsample': 0.896461276471979, 'colsample_bytree': 0.786294168339345, 'reg_alpha': 0.5580719994292282, 'reg_lambda': 0.6675126032686078}. Best is trial 12 with value: 0.6749847954122309.
# [I 2025-07-05 02:38:56,929] Trial 14 finished with value: 0.6369899460061991 and parameters: {'vector_size': 100, 'window': 6, 'min_count': 4, 'sg': 1, 'epochs': 17, 'n_estimators': 147, 'max_depth': 5, 'learning_rate': 0.19848307964622078, 'subsample': 0.9894728087201238, 'colsample_bytree': 0.934429125910761, 'reg_alpha': 0.7871464458547138, 'reg_lambda': 0.39167943544481776}. Best is trial 12 with value: 0.6749847954122309.
# [I 2025-07-05 02:39:27,270] Trial 15 finished with value: 0.6173674929379177 and parameters: {'vector_size': 100, 'window': 4, 'min_count': 7, 'sg': 1, 'epochs': 12, 'n_estimators': 225, 'max_depth': 9, 'learning_rate': 0.15717261160041338, 'subsample': 0.774439933428912, 'colsample_bytree': 0.817947631570922, 'reg_alpha': 0.7398855565382545, 'reg_lambda': 0.5895374498936983}. Best is trial 12 with value: 0.6749847954122309.
# [I 2025-07-05 02:40:27,633] Trial 16 finished with value: 0.667977819940941 and parameters: {'vector_size': 100, 'window': 5, 'min_count': 6, 'sg': 1, 'epochs': 16, 'n_estimators': 161, 'max_depth': 4, 'learning_rate': 0.22643196491520282, 'subsample': 0.8809530697784848, 'colsample_bytree': 0.9205087143024173, 'reg_alpha': 0.5466415607570495, 'reg_lambda': 0.20136362092288296}. Best is trial 12 with value: 0.6749847954122309.
# [I 2025-07-05 02:41:51,529] Trial 17 finished with value: 0.6699544171475141 and parameters: {'vector_size': 300, 'window': 6, 'min_count': 4, 'sg': 1, 'epochs': 15, 'n_estimators': 98, 'max_depth': 4, 'learning_rate': 0.2960034250215564, 'subsample': 0.8075301549946484, 'colsample_bytree': 0.9354214840371198, 'reg_alpha': 0.4519564123147768, 'reg_lambda': 0.12437786790936967}. Best is trial 12 with value: 0.6749847954122309.
# [I 2025-07-05 02:43:19,452] Trial 18 finished with value: 0.6437955865768276 and parameters: {'vector_size': 300, 'window': 6, 'min_count': 4, 'sg': 1, 'epochs': 14, 'n_estimators': 98, 'max_depth': 6, 'learning_rate': 0.29729251803145595, 'subsample': 0.8124689051264061, 'colsample_bytree': 0.952950147046211, 'reg_alpha': 0.45330628107815096, 'reg_lambda': 0.012881412833306155}. Best is trial 12 with value: 0.6749847954122309.
# [I 2025-07-05 02:44:27,573] Trial 19 finished with value: 0.6431225852804311 and parameters: {'vector_size': 300, 'window': 6, 'min_count': 4, 'sg': 1, 'epochs': 11, 'n_estimators': 94, 'max_depth': 4, 'learning_rate': 0.11776954913542376, 'subsample': 0.7049411466768691, 'colsample_bytree': 0.6114948874411065, 'reg_alpha': 0.16434365252616934, 'reg_lambda': 0.22692420851109593}. Best is trial 12 with value: 0.6749847954122309.
# Best macro-F1: 0.6749847954122309
# Best hyperparameters: {'vector_size': 100, 'window': 6, 'min_count': 5, 'sg': 1, 'epochs': 10, 'n_estimators': 126, 'max_depth': 3, 'learning_rate': 0.20396231249344568, 'subsample': 0.8834113249233835, 'colsample_bytree': 0.927082500165246, 'reg_alpha': 0.6028231464816249, 'reg_lambda': 0.9980071027057287}

# %%
best = study.best_params
sentences = [word_tokenize(txt) for txt in train_df["text"].astype(str)]
w2v_final = Word2Vec(
    sentences   = sentences,
    vector_size = best["vector_size"],
    window      = best["window"],
    min_count   = best["min_count"],
    sg          = best["sg"],
    epochs      = best["epochs"],
    workers     = 4,
    seed        = 42
)

# %%
# average word2vec vectors for a document
def doc_vector(doc):
    toks = word_tokenize(str(doc))
    vecs = [w2v_final.wv[t] for t in toks if t in w2v_final.wv]
    return np.mean(vecs, axis=0) if vecs else np.zeros(w2v_final.vector_size)

# %%
# Build feature matrices
train_df["clean_text"] = train_df["text"].astype(str).apply(clean_text_pipeline)
test_df ["clean_text"] = test_df ["text"].astype(str).apply(clean_text_pipeline)
X_train = np.vstack(train_df["clean_text"].apply(doc_vector).tolist())
X_test  = np.vstack(test_df ["clean_text"].apply(doc_vector).tolist())
y_train = train_df["sentiment_id"]
y_test  = test_df ["sentiment_id"]

# %%
from xgboost import XGBClassifier

# %%
clf_final = XGBClassifier(
    objective        = "multi:softmax",   
    num_class        = 3,                 # 3 class
    eval_metric      = "mlogloss",
    random_state     = 42,
    n_estimators     = best["n_estimators"],
    max_depth        = best["max_depth"],
    learning_rate    = best["learning_rate"],
    subsample        = best["subsample"],
    colsample_bytree = best["colsample_bytree"],
    reg_alpha        = best["reg_alpha"],
    reg_lambda       = best["reg_lambda"]
)
clf_final.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.927082500165246, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='mlogloss', feature_types=None, feature_weights=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.20396231249344568,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=126, n_jobs=None, num_class=3, ...)

# %%
y_test_pred = clf_final.predict(X_test)
print(classification_report(y_test,y_test_pred,target_names=["Negative", "Neutral", "Positive"]))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.74      0.69      0.72       160
#      Neutral       0.58      0.28      0.38       101
#     Positive       0.89      0.97      0.93       739
#
#     accuracy                           0.86      1000
#    macro avg       0.74      0.65      0.68      1000
# weighted avg       0.84      0.86      0.84      1000

# %%
cm = confusion_matrix(test_df["sentiment_id"], y_test_pred)
labels = ["Negative", "Neutral", "Positive"]

fig, ax = plt.subplots()
im = ax.imshow(cm, cmap="Blues")
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

ax.set_xticks(np.arange(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticks(np.arange(len(labels)))
ax.set_yticklabels(labels)
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_title("Confusion Matrix")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha="center", va="center")

plt.tight_layout()
plt.show()

# %%
joblib.dump(clf_final, "XGB_word2vec_experiment3b.pkl")
# Out:
# ['XGB_word2vec_experiment3b.pkl']
