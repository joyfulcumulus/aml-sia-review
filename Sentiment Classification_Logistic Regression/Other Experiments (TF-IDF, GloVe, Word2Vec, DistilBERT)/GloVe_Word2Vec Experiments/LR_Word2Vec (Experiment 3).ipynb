# %% [markdown]
# ## Logistic Regression Experiments

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import random
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
from sklearn.metrics import f1_score
import optuna
from optuna.samplers import TPESampler
import joblib

# %%
random.seed(42)
np.random.seed(42)

# %% [markdown]
# - Load the train and test files

# %%
train_df = pd.read_csv("train_data.csv")
val_df  = pd.read_csv("val_data.csv")
test_df  = pd.read_csv("test_data.csv")

# %%
print(f"Train: {len(train_df):>6} rows")
print(f" Val : {len(val_df):>6} rows")
print(f" Test: {len(test_df):>6} rows")
# Out:
# Train:   8000 rows
#  Val :   1000 rows
#  Test:   1000 rows

# %% [markdown]
# ## Word2Vec - Experiment 3 (Word2Vec trained on SIA reviews)

# %%
def w2v_features(texts, vector_size, window, min_count, sg, epochs, workers):
    tok = texts.astype(str).apply(word_tokenize)
    model = Word2Vec(
      sentences   = tok.tolist(),
      vector_size = vector_size,
      window      = window,
      min_count   = min_count,
      sg          = sg,
      epochs      = epochs,
      workers     = workers,
      seed        = 42
    )
    # avg pooling
    def dv(toks):
        vecs = [model.wv[w] for w in toks if w in model.wv]
        return np.mean(vecs, axis=0) if vecs else np.zeros(vector_size)
    return np.vstack(tok.apply(dv).values), model

# %%
train_texts = train_df["text"].astype(str)
val_texts   = val_df["text"].astype(str)
y_train = train_df["sentiment_id"]
y_val   = val_df["sentiment_id"]

# %% [markdown]
# - Hyperparameter tuning

# %%
def objective(trial):
    # Word2Vec params
    vs = trial.suggest_int("vector_size", 100, 300, step=100)
    win   = trial.suggest_int("window", 3, 7)
    mc    = trial.suggest_int("min_count", 1, 10)
    sg    = trial.suggest_int("sg", 0, 1)       # 0=CBOW, 1=skip-gram
    epochs= trial.suggest_int("epochs",5,20)
    X_tr, w2v = w2v_features(train_texts, vs, win, mc, sg, epochs, workers=4)
    X_va      = np.vstack(val_texts.astype(str)
                          .apply(lambda d: np.mean(
                              [w2v.wv[w] for w in word_tokenize(d) if w in w2v.wv],
                              axis=0) if d else np.zeros(vs)
                          ).values)
    # LR params
    C = trial.suggest_float("C", 1e-3, 1e3, log=True)
    combo = trial.suggest_categorical("penalty_solver",
                                      ["l1_saga","l2_lbfgs","l2_sag","l2_saga"])
    p,s = combo.split("_")
    clf = LogisticRegression(C=C, penalty=p, solver=s,
                             class_weight="balanced",
                             max_iter=10000, random_state=42)
    clf.fit(X_tr, y_train)
    preds = clf.predict(X_va)
    return f1_score(y_val, preds, average="macro")

# %%
sampler = TPESampler(seed=42, n_startup_trials=10)
study   = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=20)
print("Best macro-F1:", study.best_value)
print("Best hyperparameters:", study.best_params)
# Out:
# [I 2025-06-22 00:10:24,375] A new study created in memory with name: no-name-b9d2640e-6ab5-4fb8-bde5-7b403fd1c8ec
# [I 2025-06-22 00:10:32,536] Trial 0 finished with value: 0.5977086615978003 and parameters: {'vector_size': 200, 'window': 7, 'min_count': 8, 'sg': 1, 'epochs': 7, 'C': 0.00862913219007186, 'penalty_solver': 'l2_lbfgs'}. Best is trial 0 with value: 0.5977086615978003.
# [I 2025-06-22 00:10:35,714] Trial 1 finished with value: 0.5937998518003501 and parameters: {'vector_size': 100, 'window': 7, 'min_count': 9, 'sg': 0, 'epochs': 7, 'C': 0.012601639723276799, 'penalty_solver': 'l2_lbfgs'}. Best is trial 0 with value: 0.5977086615978003.
# [I 2025-06-22 00:10:50,521] Trial 2 finished with value: 0.652840960580587 and parameters: {'vector_size': 200, 'window': 3, 'min_count': 3, 'sg': 0, 'epochs': 12, 'C': 51.41096648805749, 'penalty_solver': 'l2_sag'}. Best is trial 2 with value: 0.652840960580587.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-22 00:12:26,560] Trial 3 finished with value: 0.6317086830151316 and parameters: {'vector_size': 200, 'window': 3, 'min_count': 1, 'sg': 1, 'epochs': 20, 'C': 70.85721663941601, 'penalty_solver': 'l2_sag'}. Best is trial 2 with value: 0.652840960580587.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-22 00:13:18,219] Trial 4 finished with value: 0.6560705919700421 and parameters: {'vector_size': 100, 'window': 5, 'min_count': 1, 'sg': 1, 'epochs': 9, 'C': 9.443515687962682, 'penalty_solver': 'l2_sag'}. Best is trial 4 with value: 0.6560705919700421.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-22 00:16:20,419] Trial 5 finished with value: 0.6788226333041051 and parameters: {'vector_size': 300, 'window': 6, 'min_count': 10, 'sg': 1, 'epochs': 14, 'C': 339.8172415010595, 'penalty_solver': 'l2_saga'}. Best is trial 5 with value: 0.6788226333041051.
# [I 2025-06-22 00:16:25,660] Trial 6 finished with value: 0.6491152122464556 and parameters: {'vector_size': 200, 'window': 4, 'min_count': 9, 'sg': 0, 'epochs': 9, 'C': 1.803750643128185, 'penalty_solver': 'l2_saga'}. Best is trial 5 with value: 0.6788226333041051.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-22 00:22:08,589] Trial 7 finished with value: 0.6824663854735228 and parameters: {'vector_size': 300, 'window': 3, 'min_count': 1, 'sg': 1, 'epochs': 16, 'C': 23.66154006460317, 'penalty_solver': 'l1_saga'}. Best is trial 7 with value: 0.6824663854735228.
# [I 2025-06-22 00:22:14,033] Trial 8 finished with value: 0.6252119838643575 and parameters: {'vector_size': 300, 'window': 6, 'min_count': 4, 'sg': 0, 'epochs': 9, 'C': 0.08935110590331861, 'penalty_solver': 'l2_sag'}. Best is trial 7 with value: 0.6824663854735228.
# [I 2025-06-22 00:22:28,942] Trial 9 finished with value: 0.6947809691324712 and parameters: {'vector_size': 100, 'window': 6, 'min_count': 8, 'sg': 1, 'epochs': 17, 'C': 0.9178539435251557, 'penalty_solver': 'l1_saga'}. Best is trial 9 with value: 0.6947809691324712.
# [I 2025-06-22 00:22:42,575] Trial 10 finished with value: 0.6615111435542748 and parameters: {'vector_size': 100, 'window': 5, 'min_count': 7, 'sg': 1, 'epochs': 20, 'C': 0.2266793136059909, 'penalty_solver': 'l1_saga'}. Best is trial 9 with value: 0.6947809691324712.
# [I 2025-06-22 00:23:08,955] Trial 11 finished with value: 0.6867680576504105 and parameters: {'vector_size': 300, 'window': 4, 'min_count': 6, 'sg': 1, 'epochs': 16, 'C': 4.468506597088343, 'penalty_solver': 'l1_saga'}. Best is trial 9 with value: 0.6947809691324712.
# [I 2025-06-22 00:23:19,986] Trial 12 finished with value: 0.6797274231381419 and parameters: {'vector_size': 100, 'window': 4, 'min_count': 6, 'sg': 1, 'epochs': 17, 'C': 1.285153472360623, 'penalty_solver': 'l1_saga'}. Best is trial 9 with value: 0.6947809691324712.
# [I 2025-06-22 00:23:41,816] Trial 13 finished with value: 0.6594661578349134 and parameters: {'vector_size': 300, 'window': 6, 'min_count': 5, 'sg': 1, 'epochs': 17, 'C': 0.2120657624845461, 'penalty_solver': 'l1_saga'}. Best is trial 9 with value: 0.6947809691324712.
# [I 2025-06-22 00:23:58,491] Trial 14 finished with value: 0.7024024557030937 and parameters: {'vector_size': 200, 'window': 4, 'min_count': 7, 'sg': 1, 'epochs': 14, 'C': 4.674855236819771, 'penalty_solver': 'l1_saga'}. Best is trial 14 with value: 0.7024024557030937.
# [I 2025-06-22 00:24:16,534] Trial 15 finished with value: 0.6816314446676475 and parameters: {'vector_size': 100, 'window': 5, 'min_count': 7, 'sg': 1, 'epochs': 13, 'C': 956.8050758975276, 'penalty_solver': 'l1_saga'}. Best is trial 14 with value: 0.7024024557030937.
# [I 2025-06-22 00:24:26,669] Trial 16 finished with value: 0.061156524371783226 and parameters: {'vector_size': 200, 'window': 6, 'min_count': 8, 'sg': 1, 'epochs': 11, 'C': 0.001342041841590395, 'penalty_solver': 'l1_saga'}. Best is trial 14 with value: 0.7024024557030937.
# [I 2025-06-22 00:24:31,785] Trial 17 finished with value: 0.6417107728730266 and parameters: {'vector_size': 100, 'window': 4, 'min_count': 10, 'sg': 0, 'epochs': 15, 'C': 0.503418527722374, 'penalty_solver': 'l1_saga'}. Best is trial 14 with value: 0.7024024557030937.
# [I 2025-06-22 00:24:48,963] Trial 18 finished with value: 0.6422315100761627 and parameters: {'vector_size': 200, 'window': 7, 'min_count': 7, 'sg': 1, 'epochs': 18, 'C': 0.04880738700100653, 'penalty_solver': 'l2_lbfgs'}. Best is trial 14 with value: 0.7024024557030937.
# [I 2025-06-22 00:25:05,244] Trial 19 finished with value: 0.6832695368922446 and parameters: {'vector_size': 200, 'window': 5, 'min_count': 5, 'sg': 1, 'epochs': 19, 'C': 5.990089331597949, 'penalty_solver': 'l2_saga'}. Best is trial 14 with value: 0.7024024557030937.
# Best macro-F1: 0.7024024557030937
# Best hyperparameters: {'vector_size': 200, 'window': 4, 'min_count': 7, 'sg': 1, 'epochs': 14, 'C': 4.674855236819771, 'penalty_solver': 'l1_saga'}

# %% [markdown]
# - Applying Optimal Parameters for Retraining and Evaluation on the Test Set

# %%
best = study.best_params

sentences = (train_texts.apply(word_tokenize).tolist())

w2v_final = Word2Vec(
    sentences   = sentences,
    vector_size = best["vector_size"],
    window      = best["window"],
    min_count   = best["min_count"],
    sg          = best["sg"],
    epochs      = best["epochs"],
    workers     = 4,
    seed        = 42)

# %%
# average word2vec vectors for a document
def doc_vector(doc):
    tokens = word_tokenize(str(doc))
    vecs   = [w2v_final.wv[t] for t in tokens if t in w2v_final.wv]
    return np.mean(vecs, axis=0) if vecs else np.zeros(w2v_final.vector_size)

# %%
# Build feature matrices
X_train = np.vstack(train_texts.apply(doc_vector).values)
X_test  = np.vstack(test_df["text"].astype(str).apply(doc_vector).values)
y_train = train_df["sentiment_id"]
y_test  = test_df ["sentiment_id"]

# %%
# Train classifier with best params
penalty, solver = best["penalty_solver"].split("_")
clf_final = LogisticRegression(
    C            = best["C"],
    penalty      = penalty,
    solver       = solver,
    class_weight = "balanced",
    random_state = 42,
    max_iter     = 10000,
)
clf_final.fit(X_train, y_train)
# Out:
# LogisticRegression(C=4.674855236819771, class_weight='balanced', max_iter=10000,
#                    penalty='l1', random_state=42, solver='saga')

# %%
y_test_pred = clf_final.predict(X_test)
print(classification_report(y_test,y_test_pred,target_names=["Negative", "Neutral", "Positive"]))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.68      0.72      0.70       160
#      Neutral       0.33      0.63      0.43       101
#     Positive       0.98      0.84      0.90       739
#
#     accuracy                           0.80      1000
#    macro avg       0.66      0.73      0.68      1000
# weighted avg       0.86      0.80      0.82      1000

# %%
joblib.dump(clf_final, "lr_word2vec_experiment3.pkl")
# Out:
# ['lr_word2vec_experiment3.pkl']
