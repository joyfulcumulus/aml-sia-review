# %% [markdown]
# ## Logistic Regression Experiments

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import random
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
from sklearn.metrics import f1_score
import optuna
from optuna.samplers import TPESampler
import joblib
import gensim.downloader as api

# %%
random.seed(42)
np.random.seed(42)

# %% [markdown]
# - Load the train and test files

# %%
train_df = pd.read_csv("train_data.csv")
val_df  = pd.read_csv("val_data.csv")
test_df  = pd.read_csv("test_data.csv")

# %%
print(f"Train: {len(train_df):>6} rows")
print(f" Val : {len(val_df):>6} rows")
print(f" Test: {len(test_df):>6} rows")
# Out:
# Train:   8000 rows
#  Val :   1000 rows
#  Test:   1000 rows

# %% [markdown]
# ## Word2Vec - Experiment 1 (GloVe Twitter Word2Vec)

# %%
# Load the pre-trained GloVe Twitter vectors 
wv = api.load("glove-twitter-200")

# %%
# helper to compute mean embedding for a document
def doc_vector(doc, wv_model):
    tokens = [tok for tok in doc.split() if tok in wv_model]
    if not tokens:
        return np.zeros(wv_model.vector_size)
    return np.mean([wv_model[t] for t in tokens], axis=0)

# %%
# Build feature matrices from raw text
X_train = np.vstack(train_df["text"].astype(str).apply(lambda d: doc_vector(d, wv)))
X_val   = np.vstack(val_df  ["text"].astype(str).apply(lambda d: doc_vector(d, wv)))
X_test  = np.vstack(test_df ["text"].astype(str).apply(lambda d: doc_vector(d, wv)))

y_train = train_df["sentiment_id"]
y_val   = val_df  ["sentiment_id"]
y_test  = test_df ["sentiment_id"]

# %% [markdown]
# - Hyperparameter tuning

# %%
def objective(trial):
    C = trial.suggest_float("C", 1e-3, 1e3, log=True)

    combo = trial.suggest_categorical(
        "penalty_solver",
        ["l1_saga", "l2_lbfgs", "l2_sag", "l2_saga"]
    )
    penalty, solver = combo.split("_")

    clf = LogisticRegression(
        C=C,
        penalty=penalty,
        solver=solver,
        class_weight="balanced",
        max_iter=10000,
        random_state=42,
    )
    clf.fit(X_train, y_train)

    preds = clf.predict(X_val)
    return f1_score(y_val, preds, average="macro")

# %%
sampler = TPESampler(seed=42)
study   = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=20)

print("Best macro-F1:", study.best_value)
print("Best params:")
for k, v in study.best_params.items():
    print(f"  {k}: {v}")
# Out:
# [I 2025-06-21 23:26:27,432] A new study created in memory with name: no-name-4e7d5d95-4d5a-4514-b7cf-cc73370d7c80
# [I 2025-06-21 23:26:29,523] Trial 0 finished with value: 0.6201421486752162 and parameters: {'C': 0.17670169402947947, 'penalty_solver': 'l1_saga'}. Best is trial 0 with value: 0.6201421486752162.
# [I 2025-06-21 23:26:29,649] Trial 1 finished with value: 0.5729218668495886 and parameters: {'C': 0.00862913219007186, 'penalty_solver': 'l2_lbfgs'}. Best is trial 0 with value: 0.6201421486752162.
# [I 2025-06-21 23:26:29,801] Trial 2 finished with value: 0.2833045811769216 and parameters: {'C': 0.0013289448722869186, 'penalty_solver': 'l1_saga'}. Best is trial 0 with value: 0.6201421486752162.
# [I 2025-06-21 23:26:29,862] Trial 3 finished with value: 0.586468195952845 and parameters: {'C': 0.012601639723276799, 'penalty_solver': 'l2_lbfgs'}. Best is trial 0 with value: 0.6201421486752162.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:28:20,622] Trial 4 finished with value: 0.6329375238745438 and parameters: {'C': 4.68940096353769, 'penalty_solver': 'l2_saga'}. Best is trial 4 with value: 0.6329375238745438.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:29:43,357] Trial 5 finished with value: 0.5604980169480197 and parameters: {'C': 51.41096648805749, 'penalty_solver': 'l2_sag'}. Best is trial 4 with value: 0.6329375238745438.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:31:34,394] Trial 6 finished with value: 0.6336078036451237 and parameters: {'C': 4.418441521199721, 'penalty_solver': 'l2_saga'}. Best is trial 6 with value: 0.6336078036451237.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:33:11,510] Trial 7 finished with value: 0.6457701116450699 and parameters: {'C': 70.85721663941601, 'penalty_solver': 'l2_sag'}. Best is trial 7 with value: 0.6457701116450699.
# [I 2025-06-21 23:33:11,691] Trial 8 finished with value: 0.5605856106430295 and parameters: {'C': 0.0053979568559964445, 'penalty_solver': 'l2_sag'}. Best is trial 7 with value: 0.6457701116450699.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:34:52,559] Trial 9 finished with value: 0.33429415914920924 and parameters: {'C': 9.443515687962682, 'penalty_solver': 'l2_sag'}. Best is trial 7 with value: 0.6457701116450699.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:36:17,261] Trial 10 finished with value: 0.5418918763609764 and parameters: {'C': 722.0410669062029, 'penalty_solver': 'l2_sag'}. Best is trial 7 with value: 0.6457701116450699.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:38:08,028] Trial 11 finished with value: 0.6374815430047988 and parameters: {'C': 219.96291327140094, 'penalty_solver': 'l2_saga'}. Best is trial 7 with value: 0.6457701116450699.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:39:58,586] Trial 12 finished with value: 0.639869240132151 and parameters: {'C': 778.6558070420779, 'penalty_solver': 'l2_saga'}. Best is trial 7 with value: 0.6457701116450699.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:41:49,016] Trial 13 finished with value: 0.6360514441748945 and parameters: {'C': 79.97902887556067, 'penalty_solver': 'l2_saga'}. Best is trial 7 with value: 0.6457701116450699.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:43:13,569] Trial 14 finished with value: 0.624204365654499 and parameters: {'C': 633.4559550390725, 'penalty_solver': 'l2_sag'}. Best is trial 7 with value: 0.6457701116450699.
# [I 2025-06-21 23:43:14,530] Trial 15 finished with value: 0.6366901631578733 and parameters: {'C': 0.39341437345874847, 'penalty_solver': 'l2_saga'}. Best is trial 7 with value: 0.6457701116450699.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:46:45,027] Trial 16 finished with value: 0.637820886681401 and parameters: {'C': 47.06582993948434, 'penalty_solver': 'l1_saga'}. Best is trial 7 with value: 0.6457701116450699.
# [I 2025-06-21 23:46:46,309] Trial 17 finished with value: 0.6322816343949392 and parameters: {'C': 22.117837924422574, 'penalty_solver': 'l2_lbfgs'}. Best is trial 7 with value: 0.6457701116450699.
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-06-21 23:48:35,528] Trial 18 finished with value: 0.6525394571883792 and parameters: {'C': 156.1478881953411, 'penalty_solver': 'l2_saga'}. Best is trial 18 with value: 0.6525394571883792.
# [I 2025-06-21 23:48:38,731] Trial 19 finished with value: 0.6399699615131887 and parameters: {'C': 0.962201550165691, 'penalty_solver': 'l2_sag'}. Best is trial 18 with value: 0.6525394571883792.
# Best macro-F1: 0.6525394571883792
# Best params:
#   C: 156.1478881953411
#   penalty_solver: l2_saga

# %%
best = study.best_params

pipeline = Pipeline([
  ("clf", LogisticRegression(
      C            = best["C"],
      penalty      = best["penalty_solver"].split("_")[0],
      solver       = best["penalty_solver"].split("_")[1],
      class_weight = "balanced",
      random_state = 42,
      max_iter     = 10000
  ))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# /opt/miniconda3/envs/text/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Pipeline(steps=[('clf',
#                  LogisticRegression(C=156.1478881953411,
#                                     class_weight='balanced', max_iter=10000,
#                                     random_state=42, solver='saga'))])

# %%
y_pred = pipeline.predict(X_test)
print(classification_report(test_df["sentiment_id"],y_pred,target_names=["Negative", "Neutral", "Positive"]))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.61      0.80      0.69       160
#      Neutral       0.35      0.48      0.40       101
#     Positive       0.95      0.84      0.89       739
#
#     accuracy                           0.80      1000
#    macro avg       0.64      0.71      0.66      1000
# weighted avg       0.84      0.80      0.81      1000

# %%
# Plot the confusion matrix 
cm = confusion_matrix(test_df["sentiment_id"], y_pred)
labels = ["Negative", "Neutral", "Positive"]

fig, ax = plt.subplots()
im = ax.imshow(cm, cmap="Blues")        
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)  
ax.set_xticks(np.arange(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticks(np.arange(len(labels)))
ax.set_yticklabels(labels)
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_title("Confusion Matrix")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha="center", va="center")

plt.tight_layout()
plt.show()

# %%
joblib.dump(pipeline, "lr_word2vec_experiment1.pkl")
# Out:
# ['lr_word2vec_experiment1.pkl']

# %%
def oov_rate(texts, wv_model):
    total, oov = 0, 0
    for doc in texts:
        for tok in str(doc).split():
            total += 1
            if tok not in wv_model:
                oov += 1
    return oov/total

print("GloVe-Twitter OOV:", oov_rate(train_df["text"], wv))
# Out:
# GloVe-Twitter OOV: 0.22578407727792613
