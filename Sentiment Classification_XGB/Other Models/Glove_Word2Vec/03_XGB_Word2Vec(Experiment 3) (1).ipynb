# %% [markdown]
# ## XGB Regression Experiments

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import random
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
from sklearn.metrics import f1_score
import optuna
from optuna.samplers import TPESampler
import joblib
from xgboost import XGBClassifier

# %%
random.seed(42)
np.random.seed(42)

# %% [markdown]
# - Load the train and test files

# %%
train_df = pd.read_csv("train_data.csv")
val_df  = pd.read_csv("val_data.csv")
test_df  = pd.read_csv("test_data.csv")

# %%
print(f"Train: {len(train_df):>6} rows")
print(f" Val : {len(val_df):>6} rows")
print(f" Test: {len(test_df):>6} rows")
# Out:
# Train:   8000 rows
#  Val :   1000 rows
#  Test:   1000 rows

# %% [markdown]
# ## Word2Vec - Experiment 3 (Word2Vec trained on SIA reviews)

# %%
def w2v_features(texts, vector_size, window, min_count, sg, epochs, workers):
    tok = texts.astype(str).apply(word_tokenize)
    model = Word2Vec(
      sentences   = tok.tolist(),
      vector_size = vector_size,
      window      = window,
      min_count   = min_count,
      sg          = sg,
      epochs      = epochs,
      workers     = workers,
      seed        = 42
    )
    # avg pooling
    def dv(toks):
        vecs = [model.wv[w] for w in toks if w in model.wv]
        return np.mean(vecs, axis=0) if vecs else np.zeros(vector_size)
    return np.vstack(tok.apply(dv).values), model

# %%
train_texts = train_df["text"].astype(str)
val_texts   = val_df["text"].astype(str)
y_train = train_df["sentiment_id"]
y_val   = val_df["sentiment_id"]

# %% [markdown]
# - Applying Optimal Parameters for Retraining and Evaluation on the Test Set

# %%
def objective(trial):
    # Word2Vec params
    vs = trial.suggest_int("vector_size", 100, 300, step=100)
    win   = trial.suggest_int("window", 3, 7)
    mc    = trial.suggest_int("min_count", 1, 10)
    sg    = trial.suggest_int("sg", 0, 1)       # 0=CBOW, 1=skip-gram
    epochs= trial.suggest_int("epochs",5,20)
    X_tr, w2v = w2v_features(train_texts, vs, win, mc, sg, epochs, workers=4)
    X_va      = np.vstack(val_texts.astype(str)
                          .apply(lambda d: np.mean(
                              [w2v.wv[w] for w in word_tokenize(d) if w in w2v.wv],
                              axis=0) if d else np.zeros(vs)
                          ).values)

    # --- XGBoost hyperparameters ---
    n_estimators     = trial.suggest_int("n_estimators", 50, 300)
    max_depth        = trial.suggest_int("max_depth", 3, 10)
    learning_rate    = trial.suggest_float("learning_rate", 0.01, 0.3)
    subsample        = trial.suggest_float("subsample", 0.6, 1.0)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.6, 1.0)
    reg_alpha        = trial.suggest_float("reg_alpha", 0.0, 1.0)
    reg_lambda       = trial.suggest_float("reg_lambda", 0.0, 1.0)

    clf = XGBClassifier(
        objective        = "multi:softmax",  # or "binary:logistic" if binary
        num_class        = 3,                # adjust to your number of classes
        eval_metric      = "mlogloss",
        random_state     = 42,
        n_estimators     = n_estimators,
        max_depth        = max_depth,
        learning_rate    = learning_rate,
        subsample        = subsample,
        colsample_bytree = colsample_bytree,
        reg_alpha        = reg_alpha,
        reg_lambda       = reg_lambda
    )
    clf.fit(X_tr, y_train)
    preds = clf.predict(X_va)
    return f1_score(y_val, preds, average="macro")

# %%
sampler = TPESampler(seed=42, n_startup_trials=10)
study   = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=20)
print("Best macro-F1:", study.best_value)
print("Best hyperparameters:", study.best_params)
# Out:
# [I 2025-06-24 22:59:13,062] A new study created in memory with name: no-name-b7446b82-e320-4ef3-be23-8ade6f9a05ec
# [I 2025-06-24 22:59:54,226] Trial 0 finished with value: 0.6345660389217558 and parameters: {'vector_size': 200, 'window': 7, 'min_count': 8, 'sg': 1, 'epochs': 7, 'n_estimators': 89, 'max_depth': 3, 'learning_rate': 0.2611910822747312, 'subsample': 0.8404460046972835, 'colsample_bytree': 0.8832290311184181, 'reg_alpha': 0.020584494295802447, 'reg_lambda': 0.9699098521619943}. Best is trial 0 with value: 0.6345660389217558.
# [I 2025-06-24 23:00:52,813] Trial 1 finished with value: 0.5566652275755869 and parameters: {'vector_size': 300, 'window': 4, 'min_count': 2, 'sg': 0, 'epochs': 9, 'n_estimators': 181, 'max_depth': 6, 'learning_rate': 0.09445645065743215, 'subsample': 0.8447411578889518, 'colsample_bytree': 0.6557975442608167, 'reg_alpha': 0.29214464853521815, 'reg_lambda': 0.3663618432936917}. Best is trial 0 with value: 0.6345660389217558.
# [I 2025-06-24 23:02:08,114] Trial 2 finished with value: 0.619121034912169 and parameters: {'vector_size': 200, 'window': 6, 'min_count': 2, 'sg': 1, 'epochs': 14, 'n_estimators': 61, 'max_depth': 7, 'learning_rate': 0.059451995869314544, 'subsample': 0.6260206371941118, 'colsample_bytree': 0.9795542149013333, 'reg_alpha': 0.9656320330745594, 'reg_lambda': 0.8083973481164611}. Best is trial 0 with value: 0.6345660389217558.
# [I 2025-06-24 23:02:36,817] Trial 3 finished with value: 0.5783207012709766 and parameters: {'vector_size': 100, 'window': 3, 'min_count': 7, 'sg': 0, 'epochs': 6, 'n_estimators': 174, 'max_depth': 3, 'learning_rate': 0.2737029166028468, 'subsample': 0.7035119926400067, 'colsample_bytree': 0.8650089137415928, 'reg_alpha': 0.31171107608941095, 'reg_lambda': 0.5200680211778108}. Best is trial 0 with value: 0.6345660389217558.
# [I 2025-06-24 23:04:48,144] Trial 4 finished with value: 0.6570959693750759 and parameters: {'vector_size': 200, 'window': 3, 'min_count': 10, 'sg': 1, 'epochs': 20, 'n_estimators': 274, 'max_depth': 7, 'learning_rate': 0.2773435281567039, 'subsample': 0.6353970008207678, 'colsample_bytree': 0.6783931449676581, 'reg_alpha': 0.045227288910538066, 'reg_lambda': 0.32533033076326434}. Best is trial 4 with value: 0.6570959693750759.
# [I 2025-06-24 23:06:02,678] Trial 5 finished with value: 0.5696804812368791 and parameters: {'vector_size': 200, 'window': 4, 'min_count': 9, 'sg': 0, 'epochs': 9, 'n_estimators': 186, 'max_depth': 4, 'learning_rate': 0.2426371244186715, 'subsample': 0.6298202574719083, 'colsample_bytree': 0.9947547746402069, 'reg_alpha': 0.7722447692966574, 'reg_lambda': 0.1987156815341724}. Best is trial 4 with value: 0.6570959693750759.
# [I 2025-06-24 23:07:52,251] Trial 6 finished with value: 0.565933652035347 and parameters: {'vector_size': 100, 'window': 7, 'min_count': 8, 'sg': 1, 'epochs': 17, 'n_estimators': 68, 'max_depth': 5, 'learning_rate': 0.04360202726228762, 'subsample': 0.9452413703502374, 'colsample_bytree': 0.8493192507310232, 'reg_alpha': 0.3308980248526492, 'reg_lambda': 0.06355835028602363}. Best is trial 4 with value: 0.6570959693750759.
# [I 2025-06-24 23:09:30,424] Trial 7 finished with value: 0.6590034346741277 and parameters: {'vector_size': 100, 'window': 4, 'min_count': 8, 'sg': 1, 'epochs': 19, 'n_estimators': 168, 'max_depth': 3, 'learning_rate': 0.21684098829466855, 'subsample': 0.9043140194467589, 'colsample_bytree': 0.8245108790277985, 'reg_alpha': 0.770967179954561, 'reg_lambda': 0.49379559636439074}. Best is trial 7 with value: 0.6590034346741277.
# [I 2025-06-24 23:10:37,509] Trial 8 finished with value: 0.5334613757885786 and parameters: {'vector_size': 200, 'window': 5, 'min_count': 1, 'sg': 0, 'epochs': 5, 'n_estimators': 209, 'max_depth': 5, 'learning_rate': 0.1574855004377638, 'subsample': 0.9630265895704372, 'colsample_bytree': 0.69971689165955, 'reg_alpha': 0.41038292303562973, 'reg_lambda': 0.7555511385430487}. Best is trial 7 with value: 0.6590034346741277.
# [I 2025-06-24 23:12:00,984] Trial 9 finished with value: 0.5667194345436217 and parameters: {'vector_size': 100, 'window': 3, 'min_count': 3, 'sg': 0, 'epochs': 19, 'n_estimators': 252, 'max_depth': 8, 'learning_rate': 0.2627235711544381, 'subsample': 0.9214688307596458, 'colsample_bytree': 0.6746280235544143, 'reg_alpha': 0.8925589984899778, 'reg_lambda': 0.5393422419156507}. Best is trial 7 with value: 0.6590034346741277.
# [I 2025-06-24 23:14:25,379] Trial 10 finished with value: 0.6272011126271216 and parameters: {'vector_size': 300, 'window': 5, 'min_count': 5, 'sg': 1, 'epochs': 14, 'n_estimators': 125, 'max_depth': 10, 'learning_rate': 0.18673823803172804, 'subsample': 0.746848881453861, 'colsample_bytree': 0.7518416973680894, 'reg_alpha': 0.6782537997512522, 'reg_lambda': 0.6971558983400944}. Best is trial 7 with value: 0.6590034346741277.
# [I 2025-06-24 23:16:20,678] Trial 11 finished with value: 0.6449626920428506 and parameters: {'vector_size': 100, 'window': 4, 'min_count': 10, 'sg': 1, 'epochs': 20, 'n_estimators': 296, 'max_depth': 8, 'learning_rate': 0.20837495098836134, 'subsample': 0.8798913286168203, 'colsample_bytree': 0.610547233762323, 'reg_alpha': 0.6090738634337447, 'reg_lambda': 0.35339613832696065}. Best is trial 7 with value: 0.6590034346741277.
# [I 2025-06-24 23:18:01,441] Trial 12 finished with value: 0.6615819969857236 and parameters: {'vector_size': 300, 'window': 3, 'min_count': 10, 'sg': 1, 'epochs': 17, 'n_estimators': 235, 'max_depth': 10, 'learning_rate': 0.21182011732523234, 'subsample': 0.7578369758648349, 'colsample_bytree': 0.7673042175227889, 'reg_alpha': 0.04819990075525164, 'reg_lambda': 0.31003722710560155}. Best is trial 12 with value: 0.6615819969857236.
# [I 2025-06-24 23:19:33,233] Trial 13 finished with value: 0.6459025816208751 and parameters: {'vector_size': 300, 'window': 4, 'min_count': 6, 'sg': 1, 'epochs': 17, 'n_estimators': 238, 'max_depth': 10, 'learning_rate': 0.12164069190549212, 'subsample': 0.7736698093912646, 'colsample_bytree': 0.7702357857455315, 'reg_alpha': 0.5365989257976924, 'reg_lambda': 0.009016096421198716}. Best is trial 12 with value: 0.6615819969857236.
# [I 2025-06-24 23:20:37,381] Trial 14 finished with value: 0.6253627668222697 and parameters: {'vector_size': 300, 'window': 3, 'min_count': 9, 'sg': 1, 'epochs': 17, 'n_estimators': 147, 'max_depth': 9, 'learning_rate': 0.2044321877107485, 'subsample': 0.7159249349743185, 'colsample_bytree': 0.8085935662126531, 'reg_alpha': 0.15837289469302662, 'reg_lambda': 0.21263036293030757}. Best is trial 12 with value: 0.6615819969857236.
# [I 2025-06-24 23:21:46,998] Trial 15 finished with value: 0.6692838272108638 and parameters: {'vector_size': 300, 'window': 4, 'min_count': 6, 'sg': 1, 'epochs': 15, 'n_estimators': 224, 'max_depth': 5, 'learning_rate': 0.15717261160041338, 'subsample': 0.8160380080454376, 'colsample_bytree': 0.9255974822311328, 'reg_alpha': 0.7351473671378449, 'reg_lambda': 0.6296937513399611}. Best is trial 15 with value: 0.6692838272108638.
# [I 2025-06-24 23:23:13,297] Trial 16 finished with value: 0.6509220311757984 and parameters: {'vector_size': 300, 'window': 5, 'min_count': 4, 'sg': 1, 'epochs': 12, 'n_estimators': 216, 'max_depth': 6, 'learning_rate': 0.1529476177284423, 'subsample': 0.8144186275712298, 'colsample_bytree': 0.9226264715979101, 'reg_alpha': 0.4791307165578793, 'reg_lambda': 0.636663145307566}. Best is trial 15 with value: 0.6692838272108638.
# [I 2025-06-24 23:24:35,451] Trial 17 finished with value: 0.6534087909233994 and parameters: {'vector_size': 300, 'window': 6, 'min_count': 6, 'sg': 1, 'epochs': 15, 'n_estimators': 241, 'max_depth': 5, 'learning_rate': 0.16016704242295382, 'subsample': 0.9984901537620982, 'colsample_bytree': 0.9358523659985992, 'reg_alpha': 0.16994878929106483, 'reg_lambda': 0.9035089018908093}. Best is trial 15 with value: 0.6692838272108638.
# [I 2025-06-24 23:26:32,388] Trial 18 finished with value: 0.5708357782960746 and parameters: {'vector_size': 300, 'window': 3, 'min_count': 5, 'sg': 1, 'epochs': 12, 'n_estimators': 270, 'max_depth': 9, 'learning_rate': 0.011261836495943672, 'subsample': 0.6781263811783571, 'colsample_bytree': 0.7368972068839148, 'reg_alpha': 0.7617476635857565, 'reg_lambda': 0.41863539097220615}. Best is trial 15 with value: 0.6692838272108638.
# [I 2025-06-24 23:27:23,729] Trial 19 finished with value: 0.6965525986818563 and parameters: {'vector_size': 300, 'window': 5, 'min_count': 7, 'sg': 1, 'epochs': 16, 'n_estimators': 208, 'max_depth': 4, 'learning_rate': 0.2992662502594824, 'subsample': 0.7588553432649746, 'colsample_bytree': 0.9224104398394748, 'reg_alpha': 0.6405301333656301, 'reg_lambda': 0.19603492887973462}. Best is trial 19 with value: 0.6965525986818563.
# Best macro-F1: 0.6965525986818563
# Best hyperparameters: {'vector_size': 300, 'window': 5, 'min_count': 7, 'sg': 1, 'epochs': 16, 'n_estimators': 208, 'max_depth': 4, 'learning_rate': 0.2992662502594824, 'subsample': 0.7588553432649746, 'colsample_bytree': 0.9224104398394748, 'reg_alpha': 0.6405301333656301, 'reg_lambda': 0.19603492887973462}

# %%
best = study.best_params
sentences = [word_tokenize(txt) for txt in train_df["text"].astype(str)]
w2v_final = Word2Vec(
    sentences   = sentences,
    vector_size = best["vector_size"],
    window      = best["window"],
    min_count   = best["min_count"],
    sg          = best["sg"],
    epochs      = best["epochs"],
    workers     = 4,
    seed        = 42
)

# %%
# average word2vec vectors for a document
def doc_vector(doc):
    toks = word_tokenize(str(doc))
    vecs = [w2v_final.wv[t] for t in toks if t in w2v_final.wv]
    return np.mean(vecs, axis=0) if vecs else np.zeros(w2v_final.vector_size)

# %%
# Build feature matrices
X_train = np.vstack(train_texts.apply(doc_vector).values)
X_test  = np.vstack(test_df["text"].astype(str).apply(doc_vector).values)
y_train = train_df["sentiment_id"]
y_test  = test_df ["sentiment_id"]

# %%
from xgboost import XGBClassifier

# %%
clf_final = XGBClassifier(
    objective        = "multi:softmax",   
    num_class        = 3,                 # 3 class
    eval_metric      = "mlogloss",
    random_state     = 42,
    n_estimators     = best["n_estimators"],
    max_depth        = best["max_depth"],
    learning_rate    = best["learning_rate"],
    subsample        = best["subsample"],
    colsample_bytree = best["colsample_bytree"],
    reg_alpha        = best["reg_alpha"],
    reg_lambda       = best["reg_lambda"]
)
clf_final.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9224104398394748, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='mlogloss', feature_types=None, feature_weights=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2992662502594824,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=208, n_jobs=None, num_class=3, ...)

# %%
y_test_pred = clf_final.predict(X_test)
print(classification_report(y_test,y_test_pred,target_names=["Negative", "Neutral", "Positive"]))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.78      0.69      0.73       160
#      Neutral       0.50      0.31      0.38       101
#     Positive       0.90      0.97      0.93       739
#
#     accuracy                           0.86      1000
#    macro avg       0.73      0.66      0.68      1000
# weighted avg       0.84      0.86      0.84      1000

# %%
cm = confusion_matrix(test_df["sentiment_id"], y_test_pred)
labels = ["Negative", "Neutral", "Positive"]

fig, ax = plt.subplots()
im = ax.imshow(cm, cmap="Blues")
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

ax.set_xticks(np.arange(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticks(np.arange(len(labels)))
ax.set_yticklabels(labels)
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_title("Confusion Matrix")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha="center", va="center")

plt.tight_layout()
plt.show()

# %%
joblib.dump(clf_final, "XGB_word2vec_experiment3.pkl")
# Out:
# ['XGB_word2vec_experiment3.pkl']
